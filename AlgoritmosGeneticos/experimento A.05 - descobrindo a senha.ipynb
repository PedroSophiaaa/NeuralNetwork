# %% [markdown]
# Descobrindo a senha
# ===================

# %% [markdown]
# ## Objetivo

# %% [markdown]
# Usar um algoritmo genético para descobrir uma senha.

# %% [markdown]
# ## Descrição do problema

# %% [markdown]
# Neste problema, a função objetivo deve saber a senha correta e quantificar de alguma maneira o quão perto ou longe os palpites estão da solução (veja que isso é algo que não temos no mundo real. Nenhum site irá te dizer se você está acertando ou errando seu palpite). O critério de parada deste problema é quando a senha for descoberta.

# %% [markdown]
# ## Importações

# %%
from string import printable
from funcoes import new_pop_passw, fitness_passw, tourn_sel_min, crossover_passw, mutation_passw
import random as rd

# %% [markdown]
# ## Códigos e discussão

# %% [markdown]
# ### Gerador de senha

# %%
pass_chars = printable[:-5]

# %%
def create_password(n):
    password = ""
    for i in range(n):
        password += rd.choice(pass_chars)
    return password

# %%
TAM_POP = 10
NUM_GEN = 1000
GEN_MAX = 100
PM = 0.05 # Probabilidade de mutação
PC = 0.75 # Probabilidade de cruzamento
PS = 24 # Número de caracteres da senha

TAM_CROMO = PS

PASSWORD = create_password(PS)
print("Real password: '", PASSWORD, "'", sep='')
# Out:
# Real password: 'j$I{q:<MJd{ib*E?}ht7{~f}'

# %%
PASSWORD = "pepe"
pass_chars = "abcdefghijklmnopqrstuvwxyz"
TAM_CROMO = len(PASSWORD)

# %%
gen = 1
pop = new_pop_passw(TAM_POP, TAM_CROMO, pass_chars, PASSWORD)

min_fit = float('inf')

while min_fit != 0:
    print("gen ", gen, ":", sep="")
    if gen > 1:
        pop = tourn_sel_min(pop, PASSWORD)

        pop_inds = [pop[i]["ind"] for i in pop]
        p1_list = pop_inds[0::2]
        p2_list = pop_inds[1::2]
        c = 1
        for p1, p2 in zip(p1_list, p2_list):
            filho1, filho2 = crossover_passw(p1, p2, PC)
            pop[c]["ind"] = filho1
            pop[c + 1]["ind"] = filho2
            c += 2
    for i in pop:
        curr_ind = pop[i]
        if gen > 1:
            curr_ind = mutation_passw(curr_ind, pass_chars, PM)
        curr_ind["fitness"] = fitness_passw(curr_ind["ind"], PASSWORD)
        print("\t", curr_ind)
    for i in pop:
        if pop[i]['fitness'] == 0:
            best_ind = pop[i]['ind']
            best_ind_tag = pop[i]['tag']
            min_fit = 0
            print(f'\nPassword found!\nGen: {gen}\nInd: {best_ind_tag}\nPassword: {best_ind}')
    gen += 1
    print()
# Out:
# gen 1:
# 	 {'tag': 1, 'ind': 'ecuw', 'fitness': 36}
# 	 {'tag': 2, 'ind': 'onun', 'fitness': 24}
# 	 {'tag': 3, 'ind': 'nmlr', 'fitness': 27}
# 	 {'tag': 4, 'ind': 'tjiv', 'fitness': 33}
# 	 {'tag': 5, 'ind': 'etbj', 'fitness': 45}
# 	 {'tag': 6, 'ind': 'bhjh', 'fitness': 26}
# 	 {'tag': 7, 'ind': 'afhr', 'fitness': 37}
# 	 {'tag': 8, 'ind': 'dlld', 'fitness': 24}
# 	 {'tag': 9, 'ind': 'pqmj', 'fitness': 20}
# 	 {'tag': 10, 'ind': 'pggj', 'fitness': 16}
#
# gen 2:
# sel inds: ['onun', 'onun', 'onun', 'bhjh', 'bhjh', 'pqmj', 'pggj', 'onun', 'dlld', 'dlld']
# crossover between onun and onun done.
# Crossover failed.
# Crossover failed.
# crossover between pggj and onun done.
# crossover between dlld and dlld done.
# 	 {'tag': 1, 'ind': 'onun', 'fitness': 24}
# 	 {'tag': 2, 'ind': 'onun', 'fitness': 24}
# Mutation in gen 2 in [3 : osun] with mut= 0.04200737884965644. n to s
# Mutation in gen 3 in [3 : osbn] with mut= 0.006686573565939047. u to b
# 	 {'tag': 3, 'ind': 'osbn', 'fitness': 38}
# 	 {'tag': 4, 'ind': 'bhjh', 'fitness': 26}
# 	 {'tag': 5, 'ind': 'bhjh', 'fitness': 26}
# 	 {'tag': 6, 'ind': 'pqmj', 'fitness': 20}
# Mutation in gen 3 in [7 : pnmn] with mut= 0.028254611887780556. u to m
# 	 {'tag': 7, 'ind': 'pnmn', 'fitness': 21}
# 	 {'tag': 8, 'ind': 'oggj', 'fitness': 17}
# 	 {'tag': 9, 'ind': 'dlld', 'fitness': 24}
# 	 {'tag': 10, 'ind': 'dlld', 'fitness': 24}
#
# gen 3:
# sel inds: ['pqmj', 'dlld', 'pqmj', 'dlld', 'oggj', 'onun', 'dlld', 'oggj', 'oggj', 'onun']
# crossover between pqmj and dlld done.
# crossover between pqmj and dlld done.
# crossover between oggj and onun done.
# crossover between dlld and oggj done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'pqld', 'fitness': 17}
# 	 {'tag': 2, 'ind': 'dlmj', 'fitness': 27}
# 	 {'tag': 3, 'ind': 'plld', 'fitness': 12}
# 	 {'tag': 4, 'ind': 'dqmj', 'fitness': 32}
# 	 {'tag': 5, 'ind': 'onun', 'fitness': 24}
# Mutation in gen 3 in [6 : ogxj] with mut= 0.048289133740188395. g to x
# 	 {'tag': 6, 'ind': 'ogxj', 'fitness': 16}
# Mutation in gen 4 in [7 : dllo] with mut= 0.010952078644234864. j to o
# 	 {'tag': 7, 'ind': 'dllo', 'fitness': 33}
# Mutation in gen 2 in [8 : owgd] with mut= 0.023981988792441733. g to w
# 	 {'tag': 8, 'ind': 'owgd', 'fitness': 29}
# Mutation in gen 4 in [9 : oggz] with mut= 0.042342504783250745. j to z
# 	 {'tag': 9, 'ind': 'oggz', 'fitness': 33}
# 	 {'tag': 10, 'ind': 'onun', 'fitness': 24}
#
# gen 4:
# sel inds: ['onun', 'plld', 'ogxj', 'ogxj', 'pqld', 'plld', 'owgd', 'plld', 'pqld', 'plld']
# crossover between onun and plld done.
# Crossover failed.
# crossover between pqld and plld done.
# Crossover failed.
# crossover between pqld and plld done.
# Mutation in gen 2 in [1 : osld] with mut= 0.04048153535108423. n to s
# 	 {'tag': 1, 'ind': 'osld', 'fitness': 20}
# 	 {'tag': 2, 'ind': 'plun', 'fitness': 21}
# Mutation in gen 2 in [3 : osxj] with mut= 0.028275921741538146. g to s
# 	 {'tag': 3, 'ind': 'osxj', 'fitness': 28}
# 	 {'tag': 4, 'ind': 'ogxj', 'fitness': 16}
# 	 {'tag': 5, 'ind': 'pqld', 'fitness': 17}
# 	 {'tag': 6, 'ind': 'plld', 'fitness': 12}
# Mutation in gen 1 in [7 : zwgd] with mut= 0.03379075900566497. o to z
# 	 {'tag': 7, 'ind': 'zwgd', 'fitness': 38}
# Mutation in gen 1 in [8 : glld] with mut= 0.0043919579199803715. p to g
# 	 {'tag': 8, 'ind': 'glld', 'fitness': 21}
# Mutation in gen 3 in [9 : pqud] with mut= 0.04023999410948409. l to u
# 	 {'tag': 9, 'ind': 'pqud', 'fitness': 18}
# 	 {'tag': 10, 'ind': 'plld', 'fitness': 12}
#
# gen 5:
# sel inds: ['pqld', 'ogxj', 'ogxj', 'ogxj', 'ogxj', 'plld', 'plld', 'plld', 'plld', 'pqld']
# crossover between pqld and ogxj done.
# Crossover failed.
# crossover between ogxj and plld done.
# crossover between plld and plld done.
# crossover between plld and pqld done.
# 	 {'tag': 1, 'ind': 'pqxj', 'fitness': 25}
# Mutation in gen 1 in [2 : ogld] with mut= 0.014614846627000966. o to o
# 	 {'tag': 2, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 3, 'ind': 'ogxj', 'fitness': 16}
# 	 {'tag': 4, 'ind': 'ogxj', 'fitness': 16}
# 	 {'tag': 5, 'ind': 'ogxd', 'fitness': 12}
# 	 {'tag': 6, 'ind': 'pllj', 'fitness': 16}
# 	 {'tag': 7, 'ind': 'plld', 'fitness': 12}
# 	 {'tag': 8, 'ind': 'plld', 'fitness': 12}
# 	 {'tag': 9, 'ind': 'pqld', 'fitness': 17}
# 	 {'tag': 10, 'ind': 'plld', 'fitness': 12}
#
# gen 6:
# sel inds: ['ogld', 'ogxd', 'ogld', 'pllj', 'ogxd', 'ogxd', 'ogld', 'ogxd', 'plld', 'ogxj']
# crossover between ogld and ogxd done.
# crossover between ogld and pllj done.
# crossover between ogxd and ogxd done.
# Crossover failed.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'ogxd', 'fitness': 12}
# Mutation in gen 2 in [2 : oxld] with mut= 0.023425679217724982. g to x
# 	 {'tag': 2, 'ind': 'oxld', 'fitness': 25}
# 	 {'tag': 3, 'ind': 'ollj', 'fitness': 17}
# Mutation in gen 4 in [4 : pgll] with mut= 0.03844300628880715. d to l
# 	 {'tag': 4, 'ind': 'pgll', 'fitness': 13}
# Mutation in gen 3 in [5 : oged] with mut= 0.03573277328651392. x to e
# 	 {'tag': 5, 'ind': 'oged', 'fitness': 15}
# Mutation in gen 3 in [6 : ogfd] with mut= 0.03618101067249091. x to f
# Mutation in gen 4 in [6 : ogfl] with mut= 0.04961874714033199. d to l
# 	 {'tag': 6, 'ind': 'ogfl', 'fitness': 20}
# 	 {'tag': 7, 'ind': 'ogld', 'fitness': 8}
# Mutation in gen 1 in [8 : vgxd] with mut= 0.007604388307026921. o to v
# 	 {'tag': 8, 'ind': 'vgxd', 'fitness': 17}
# 	 {'tag': 9, 'ind': 'plld', 'fitness': 12}
# 	 {'tag': 10, 'ind': 'ogxj', 'fitness': 16}
#
# gen 7:
# sel inds: ['plld', 'ogxd', 'plld', 'ogld', 'ogxd', 'ogld', 'plld', 'ogxd', 'pgll', 'ogxd']
# crossover between plld and ogxd done.
# Crossover failed.
# crossover between ogxd and ogld done.
# crossover between plld and ogxd done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'plxd', 'fitness': 16}
# 	 {'tag': 2, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 3, 'ind': 'plld', 'fitness': 12}
# 	 {'tag': 4, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 5, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 6, 'ind': 'ogxd', 'fitness': 12}
# 	 {'tag': 7, 'ind': 'plld', 'fitness': 12}
# 	 {'tag': 8, 'ind': 'ogxd', 'fitness': 12}
# 	 {'tag': 9, 'ind': 'pgll', 'fitness': 13}
# 	 {'tag': 10, 'ind': 'ogxd', 'fitness': 12}
#
# gen 8:
# sel inds: ['ogld', 'ogxd', 'ogld', 'ogld', 'ogxd', 'ogld', 'ogxd', 'ogxd', 'ogld', 'ogld']
# Crossover failed.
# Crossover failed.
# crossover between ogxd and ogld done.
# crossover between ogxd and ogxd done.
# crossover between ogld and ogld done.
# 	 {'tag': 1, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 2, 'ind': 'ogxd', 'fitness': 12}
# 	 {'tag': 3, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 4, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 5, 'ind': 'ogxd', 'fitness': 12}
# 	 {'tag': 6, 'ind': 'ogld', 'fitness': 8}
# Mutation in gen 4 in [7 : ogxa] with mut= 0.0317137077198304. d to a
# 	 {'tag': 7, 'ind': 'ogxa', 'fitness': 15}
# 	 {'tag': 8, 'ind': 'ogxd', 'fitness': 12}
# Mutation in gen 2 in [9 : oald] with mut= 0.0362825683039264. g to a
# 	 {'tag': 9, 'ind': 'oald', 'fitness': 10}
# 	 {'tag': 10, 'ind': 'ogld', 'fitness': 8}
#
# gen 9:
# sel inds: ['ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogxd', 'oald', 'ogld', 'ogld']
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# crossover between ogxd and oald done.
# crossover between ogld and ogld done.
# 	 {'tag': 1, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 2, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 3, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 4, 'ind': 'ogld', 'fitness': 8}
# Mutation in gen 4 in [5 : oglm] with mut= 0.00020518914233946806. d to m
# 	 {'tag': 5, 'ind': 'oglm', 'fitness': 15}
# 	 {'tag': 6, 'ind': 'ogld', 'fitness': 8}
# Mutation in gen 2 in [7 : ovld] with mut= 0.041714605994259246. g to v
# 	 {'tag': 7, 'ind': 'ovld', 'fitness': 23}
# 	 {'tag': 8, 'ind': 'oaxd', 'fitness': 14}
# Mutation in gen 1 in [9 : fgld] with mut= 0.034926083598482816. o to f
# 	 {'tag': 9, 'ind': 'fgld', 'fitness': 17}
# 	 {'tag': 10, 'ind': 'ogld', 'fitness': 8}
#
# gen 10:
# sel inds: ['ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'oaxd', 'ogld']
# crossover between ogld and ogld done.
# Crossover failed.
# crossover between ogld and ogld done.
# Crossover failed.
# crossover between oaxd and ogld done.
# 	 {'tag': 1, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 2, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 3, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 4, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 5, 'ind': 'ogld', 'fitness': 8}
# Mutation in gen 4 in [6 : oglt] with mut= 0.015740996406588215. d to t
# 	 {'tag': 6, 'ind': 'oglt', 'fitness': 22}
# Mutation in gen 1 in [7 : jgld] with mut= 0.02923874693316908. o to j
# 	 {'tag': 7, 'ind': 'jgld', 'fitness': 13}
# 	 {'tag': 8, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 9, 'ind': 'oald', 'fitness': 10}
# 	 {'tag': 10, 'ind': 'ogxd', 'fitness': 12}
#
# gen 11:
# sel inds: ['ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld']
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# Crossover failed.
# Crossover failed.
# crossover between ogld and ogld done.
# 	 {'tag': 1, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 2, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 3, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 4, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 5, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 6, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 7, 'ind': 'ogld', 'fitness': 8}
# Mutation in gen 3 in [8 : ogkd] with mut= 0.03281216270863663. l to k
# 	 {'tag': 8, 'ind': 'ogkd', 'fitness': 9}
# 	 {'tag': 9, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 10, 'ind': 'ogld', 'fitness': 8}
#
# gen 12:
# sel inds: ['ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld']
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# Crossover failed.
# crossover between ogld and ogld done.
# 	 {'tag': 1, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 2, 'ind': 'ogld', 'fitness': 8}
# Mutation in gen 3 in [3 : ogad] with mut= 0.015658400227034686. l to a
# 	 {'tag': 3, 'ind': 'ogad', 'fitness': 19}
# 	 {'tag': 4, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 5, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 6, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 7, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 8, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 9, 'ind': 'ogld', 'fitness': 8}
# Mutation in gen 2 in [10 : odld] with mut= 0.016468521394568447. g to d
# Mutation in gen 3 in [10 : odjd] with mut= 0.02441610620679613. l to j
# 	 {'tag': 10, 'ind': 'odjd', 'fitness': 9}
#
# gen 13:
# sel inds: ['ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld']
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# Crossover failed.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 2, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 3, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 4, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 5, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 6, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 7, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 8, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 9, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 10, 'ind': 'ogld', 'fitness': 8}
#
# gen 14:
# sel inds: ['ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld']
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# 	 {'tag': 1, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 2, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 3, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 4, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 5, 'ind': 'ogld', 'fitness': 8}
# Mutation in gen 2 in [6 : orld] with mut= 0.013289313258979196. g to r
# 	 {'tag': 6, 'ind': 'orld', 'fitness': 19}
# Mutation in gen 4 in [7 : oglv] with mut= 0.032492231599084764. d to v
# 	 {'tag': 7, 'ind': 'oglv', 'fitness': 24}
# Mutation in gen 4 in [8 : oglx] with mut= 0.04861363119996798. d to x
# 	 {'tag': 8, 'ind': 'oglx', 'fitness': 26}
# Mutation in gen 1 in [9 : ugld] with mut= 0.01968345830330631. o to u
# Mutation in gen 4 in [9 : ugll] with mut= 0.0469652006358946. d to l
# 	 {'tag': 9, 'ind': 'ugll', 'fitness': 18}
# 	 {'tag': 10, 'ind': 'ogld', 'fitness': 8}
#
# gen 15:
# sel inds: ['ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ugll', 'ogld', 'ogld', 'ogld', 'ogld']
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# crossover between ogld and ugll done.
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# Mutation in gen 2 in [1 : onld] with mut= 0.03725374492615163. g to n
# Mutation in gen 3 in [1 : onbd] with mut= 0.03923373932507579. l to b
# 	 {'tag': 1, 'ind': 'onbd', 'fitness': 25}
# 	 {'tag': 2, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 3, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 4, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 5, 'ind': 'ogll', 'fitness': 14}
# 	 {'tag': 6, 'ind': 'ugld', 'fitness': 12}
# 	 {'tag': 7, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 8, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 9, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 10, 'ind': 'ogld', 'fitness': 8}
#
# gen 16:
# sel inds: ['ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld']
# Crossover failed.
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# 	 {'tag': 1, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 2, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 3, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 4, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 5, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 6, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 7, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 8, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 9, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 10, 'ind': 'ogld', 'fitness': 8}
#
# gen 17:
# sel inds: ['ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld', 'ogld']
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# crossover between ogld and ogld done.
# 	 {'tag': 1, 'ind': 'ogld', 'fitness': 8}
# Mutation in gen 2 in [2 : ocld] with mut= 0.0015381046744757931. g to c
# Mutation in gen 3 in [2 : ocqd] with mut= 0.008444589458122986. l to q
# 	 {'tag': 2, 'ind': 'ocqd', 'fitness': 5}
# 	 {'tag': 3, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 4, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 5, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 6, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 7, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 8, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 9, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 10, 'ind': 'ogld', 'fitness': 8}
#
# gen 18:
# sel inds: ['ogld', 'ocqd', 'ogld', 'ogld', 'ocqd', 'ogld', 'ocqd', 'ocqd', 'ogld', 'ogld']
# crossover between ogld and ocqd done.
# crossover between ogld and ogld done.
# crossover between ocqd and ogld done.
# crossover between ocqd and ocqd done.
# crossover between ogld and ogld done.
# 	 {'tag': 1, 'ind': 'ogqd', 'fitness': 5}
# 	 {'tag': 2, 'ind': 'ocld', 'fitness': 8}
# 	 {'tag': 3, 'ind': 'ogld', 'fitness': 8}
# Mutation in gen 3 in [4 : ogod] with mut= 0.039009411937400595. l to o
# 	 {'tag': 4, 'ind': 'ogod', 'fitness': 5}
# 	 {'tag': 5, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 6, 'ind': 'ocqd', 'fitness': 5}
# 	 {'tag': 7, 'ind': 'ocqd', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'ocqd', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'ogld', 'fitness': 8}
# 	 {'tag': 10, 'ind': 'ogld', 'fitness': 8}
#
# gen 19:
# sel inds: ['ogqd', 'ocqd', 'ogqd', 'ogod', 'ocqd', 'ocqd', 'ogod', 'ocqd', 'ocqd', 'ogod']
# crossover between ogqd and ocqd done.
# Crossover failed.
# crossover between ocqd and ocqd done.
# crossover between ogod and ocqd done.
# crossover between ocqd and ogod done.
# Mutation in gen 4 in [1 : ogqs] with mut= 0.006795367139801001. d to s
# 	 {'tag': 1, 'ind': 'ogqs', 'fitness': 18}
# 	 {'tag': 2, 'ind': 'ocqd', 'fitness': 5}
# 	 {'tag': 3, 'ind': 'ogqd', 'fitness': 5}
# 	 {'tag': 4, 'ind': 'ogod', 'fitness': 5}
# 	 {'tag': 5, 'ind': 'ocqd', 'fitness': 5}
# 	 {'tag': 6, 'ind': 'ocqd', 'fitness': 5}
# 	 {'tag': 7, 'ind': 'ogqd', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'ocod', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'ocqd', 'fitness': 5}
# 	 {'tag': 10, 'ind': 'ogod', 'fitness': 5}
#
# gen 20:
# sel inds: ['ocqd', 'ocqd', 'ocod', 'ocqd', 'ogqd', 'ocod', 'ogqd', 'ogod', 'ogqd', 'ogod']
# Crossover failed.
# Crossover failed.
# crossover between ogqd and ocod done.
# crossover between ogqd and ogod done.
# crossover between ogqd and ogod done.
# 	 {'tag': 1, 'ind': 'ocqd', 'fitness': 5}
# 	 {'tag': 2, 'ind': 'ocqd', 'fitness': 5}
# 	 {'tag': 3, 'ind': 'ocod', 'fitness': 5}
# 	 {'tag': 4, 'ind': 'ocqd', 'fitness': 5}
# 	 {'tag': 5, 'ind': 'ogod', 'fitness': 5}
# Mutation in gen 4 in [6 : ocqc] with mut= 0.04197779489866971. d to c
# 	 {'tag': 6, 'ind': 'ocqc', 'fitness': 6}
# 	 {'tag': 7, 'ind': 'ogod', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'ogqd', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'ogod', 'fitness': 5}
# 	 {'tag': 10, 'ind': 'ogqd', 'fitness': 5}
#
# gen 21:
# sel inds: ['ogqd', 'ocqd', 'ocod', 'ocqd', 'ogod', 'ocod', 'ogod', 'ocqd', 'ogqd', 'ogod']
# crossover between ogqd and ocqd done.
# crossover between ocod and ocqd done.
# crossover between ogod and ocod done.
# crossover between ogod and ocqd done.
# crossover between ogqd and ogod done.
# 	 {'tag': 1, 'ind': 'ogqd', 'fitness': 5}
# 	 {'tag': 2, 'ind': 'ocqd', 'fitness': 5}
# Mutation in gen 2 in [3 : oxqd] with mut= 0.022326803129518624. c to x
# 	 {'tag': 3, 'ind': 'oxqd', 'fitness': 22}
# 	 {'tag': 4, 'ind': 'ocod', 'fitness': 5}
# Mutation in gen 4 in [5 : ogoh] with mut= 0.04257019823880359. d to h
# 	 {'tag': 5, 'ind': 'ogoh', 'fitness': 7}
# Mutation in gen 3 in [6 : ocpd] with mut= 0.046240628808292494. o to p
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ogqd', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'ocod', 'fitness': 5}
# Mutation in gen 3 in [9 : ogqd] with mut= 0.0357549656639945. o to q
# 	 {'tag': 9, 'ind': 'ogqd', 'fitness': 5}
# 	 {'tag': 10, 'ind': 'ogqd', 'fitness': 5}
#
# gen 22:
# sel inds: ['ocpd', 'ogqd', 'ocqd', 'ocpd', 'ogqd', 'ocpd', 'ocpd', 'ocpd', 'ogqd', 'ogqd']
# Crossover failed.
# Crossover failed.
# crossover between ogqd and ocpd done.
# Crossover failed.
# crossover between ogqd and ogqd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ogqd', 'fitness': 5}
# 	 {'tag': 3, 'ind': 'ocqd', 'fitness': 5}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ogpd', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'ocqd', 'fitness': 5}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 3 in [9 : ogid] with mut= 0.03267266655081835. q to i
# 	 {'tag': 9, 'ind': 'ogid', 'fitness': 11}
# 	 {'tag': 10, 'ind': 'ogqd', 'fitness': 5}
#
# gen 23:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ogpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ogpd and ocpd done.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 4 in [3 : ocpr] with mut= 0.0024044440105299714. d to r
# 	 {'tag': 3, 'ind': 'ocpr', 'fitness': 16}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ogpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 24:
# sel inds: ['ogpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ogpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ogpd', 'fitness': 4}
# Mutation in gen 1 in [2 : xcpd] with mut= 0.03651301843926358. o to x
# 	 {'tag': 2, 'ind': 'xcpd', 'fitness': 11}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 4 in [6 : ocpj] with mut= 0.004248665546790487. d to j
# 	 {'tag': 6, 'ind': 'ocpj', 'fitness': 8}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 25:
# sel inds: ['ogpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# Crossover failed.
# crossover between ocpd and ocpd done.
# Crossover failed.
# crossover between ocpd and ocpd done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'ogpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 4 in [7 : ocps] with mut= 0.04898020347277898. d to s
# 	 {'tag': 7, 'ind': 'ocps', 'fitness': 17}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 2 in [9 : oipd] with mut= 0.046084338141394565. c to i
# 	 {'tag': 9, 'ind': 'oipd', 'fitness': 6}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 26:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ogpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# Crossover failed.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ogpd done.
# Crossover failed.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'ogpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 3 in [8 : ocnd] with mut= 0.013364128277992271. p to n
# 	 {'tag': 8, 'ind': 'ocnd', 'fitness': 6}
# Mutation in gen 1 in [9 : dcpd] with mut= 0.030335683005786485. o to d
# Mutation in gen 2 in [9 : dgpd] with mut= 0.025779963781901394. c to g
# 	 {'tag': 9, 'ind': 'dgpd', 'fitness': 15}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 27:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ogpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ogpd and ocpd done.
# crossover between ocpd and ocpd done.
# Mutation in gen 2 in [1 : ozpd] with mut= 0.00590317012491981. c to z
# 	 {'tag': 1, 'ind': 'ozpd', 'fitness': 23}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ogpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 28:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ogpd']
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# Crossover failed.
# crossover between ocpd and ocpd done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 3 in [10 : ogqd] with mut= 0.003149532222933571. p to q
# 	 {'tag': 10, 'ind': 'ogqd', 'fitness': 5}
#
# gen 29:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# Crossover failed.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 3 in [6 : ocnd] with mut= 0.012087909666812058. p to n
# 	 {'tag': 6, 'ind': 'ocnd', 'fitness': 6}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 30:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# Crossover failed.
# Crossover failed.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 2 in [5 : olpd] with mut= 0.005798147477421578. c to l
# 	 {'tag': 5, 'ind': 'olpd', 'fitness': 9}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 31:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# Crossover failed.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 32:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# Crossover failed.
# Crossover failed.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 3 in [3 : ocyd] with mut= 0.04027698364486487. p to y
# 	 {'tag': 3, 'ind': 'ocyd', 'fitness': 13}
# Mutation in gen 3 in [4 : ocqd] with mut= 0.03653412692372282. p to q
# 	 {'tag': 4, 'ind': 'ocqd', 'fitness': 5}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 33:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# Crossover failed.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 2 in [2 : oopd] with mut= 0.026127358656366506. c to o
# 	 {'tag': 2, 'ind': 'oopd', 'fitness': 12}
# Mutation in gen 1 in [3 : ucpd] with mut= 0.03240573926975021. o to u
# 	 {'tag': 3, 'ind': 'ucpd', 'fitness': 8}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 1 in [6 : qcpd] with mut= 0.02021787738665881. o to q
# 	 {'tag': 6, 'ind': 'qcpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 2 in [8 : oopd] with mut= 0.03661638449668936. c to o
# 	 {'tag': 8, 'ind': 'oopd', 'fitness': 12}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 2 in [10 : oapd] with mut= 0.020355697707314935. c to a
# Mutation in gen 3 in [10 : oazd] with mut= 0.047002962232503. p to z
# 	 {'tag': 10, 'ind': 'oazd', 'fitness': 16}
#
# gen 34:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'qcpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between qcpd and ocpd done.
# Crossover failed.
# Mutation in gen 3 in [1 : ocpd] with mut= 0.02358454810708377. p to p
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 3 in [5 : ocod] with mut= 0.02877011021837894. p to o
# 	 {'tag': 5, 'ind': 'ocod', 'fitness': 5}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'qcpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 35:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# Crossover failed.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 1 in [8 : ccpd] with mut= 0.013164114122194315. o to c
# 	 {'tag': 8, 'ind': 'ccpd', 'fitness': 16}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 36:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# Crossover failed.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 3 in [4 : ocld] with mut= 0.022662417417666614. p to l
# 	 {'tag': 4, 'ind': 'ocld', 'fitness': 8}
# Mutation in gen 3 in [5 : ochd] with mut= 0.0265378809949659. p to h
# 	 {'tag': 5, 'ind': 'ochd', 'fitness': 12}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 3 in [8 : ocqd] with mut= 0.039521885910445254. p to q
# 	 {'tag': 8, 'ind': 'ocqd', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 37:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 2 in [3 : ospd] with mut= 0.012192767629876755. c to s
# 	 {'tag': 3, 'ind': 'ospd', 'fitness': 16}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 1 in [9 : fcpd] with mut= 0.008874086521604263. o to f
# 	 {'tag': 9, 'ind': 'fcpd', 'fitness': 13}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 38:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 39:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 3 in [2 : octd] with mut= 0.02197500467547453. p to t
# 	 {'tag': 2, 'ind': 'octd', 'fitness': 8}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 2 in [7 : odpd] with mut= 0.0458603169600138. c to d
# 	 {'tag': 7, 'ind': 'odpd', 'fitness': 3}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 40:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 2 in [4 : owpd] with mut= 0.04189194065403401. c to w
# 	 {'tag': 4, 'ind': 'owpd', 'fitness': 20}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 2 in [8 : olpd] with mut= 0.01254075716101577. c to l
# 	 {'tag': 8, 'ind': 'olpd', 'fitness': 9}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 41:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# Crossover failed.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 1 in [6 : lcpd] with mut= 0.01951156665135223. o to l
# Mutation in gen 3 in [6 : lccd] with mut= 0.0089524890444721. p to c
# 	 {'tag': 6, 'ind': 'lccd', 'fitness': 20}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 42:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# Crossover failed.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# Mutation in gen 3 in [1 : ocad] with mut= 0.0239998489959542. p to a
# 	 {'tag': 1, 'ind': 'ocad', 'fitness': 19}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 43:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# Crossover failed.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 3 in [3 : occd] with mut= 0.011829758792751832. p to c
# 	 {'tag': 3, 'ind': 'occd', 'fitness': 17}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 2 in [5 : ospd] with mut= 0.003039765141916173. c to s
# 	 {'tag': 5, 'ind': 'ospd', 'fitness': 16}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 1 in [7 : jcpd] with mut= 0.04762772319703812. o to j
# 	 {'tag': 7, 'ind': 'jcpd', 'fitness': 9}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 44:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 45:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# Crossover failed.
# Crossover failed.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 3 in [3 : ocrd] with mut= 0.04198496827721798. p to r
# 	 {'tag': 3, 'ind': 'ocrd', 'fitness': 6}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 46:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# Crossover failed.
# crossover between ocpd and ocpd done.
# Crossover failed.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 1 in [2 : scpd] with mut= 0.026193323662119905. o to s
# 	 {'tag': 2, 'ind': 'scpd', 'fitness': 6}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 4 in [9 : ocpx] with mut= 0.04106234198730463. d to x
# 	 {'tag': 9, 'ind': 'ocpx', 'fitness': 22}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 47:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# Crossover failed.
# Crossover failed.
# crossover between ocpd and ocpd done.
# Crossover failed.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 1 in [5 : icpd] with mut= 0.021986750015092205. o to i
# 	 {'tag': 5, 'ind': 'icpd', 'fitness': 10}
# Mutation in gen 4 in [6 : ocpo] with mut= 0.02454183480954275. d to o
# 	 {'tag': 6, 'ind': 'ocpo', 'fitness': 13}
# Mutation in gen 3 in [7 : ocqd] with mut= 0.045600032289077164. p to q
# 	 {'tag': 7, 'ind': 'ocqd', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 1 in [10 : ucpd] with mut= 0.0454758580789929. o to u
# 	 {'tag': 10, 'ind': 'ucpd', 'fitness': 8}
#
# gen 48:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# Crossover failed.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 4 in [4 : ocpj] with mut= 0.045110484302023135. d to j
# 	 {'tag': 4, 'ind': 'ocpj', 'fitness': 8}
# Mutation in gen 2 in [5 : ompd] with mut= 0.013987891014711096. c to m
# 	 {'tag': 5, 'ind': 'ompd', 'fitness': 10}
# Mutation in gen 3 in [6 : oczd] with mut= 0.04565756482628869. p to z
# 	 {'tag': 6, 'ind': 'oczd', 'fitness': 14}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpd', 'fitness': 4}
#
# gen 49:
# sel inds: ['ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd']
# crossover between ocpd and ocpd done.
# Crossover failed.
# Crossover failed.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 4 in [5 : ocpe] with mut= 0.009380784079970117. d to e
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 4 in [6 : ocpl] with mut= 0.026290735126570763. d to l
# 	 {'tag': 6, 'ind': 'ocpl', 'fitness': 10}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 2 in [10 : ojpd] with mut= 0.0018110117225276223. c to j
# 	 {'tag': 10, 'ind': 'ojpd', 'fitness': 7}
#
# gen 50:
# sel inds: ['ocpe', 'ocpd', 'ocpe', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpd', 'ocpe', 'ocpd']
# crossover between ocpe and ocpd done.
# Crossover failed.
# crossover between ocpd and ocpd done.
# crossover between ocpd and ocpd done.
# crossover between ocpe and ocpd done.
# 	 {'tag': 1, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 1 in [5 : mcpd] with mut= 0.024828305312109777. o to m
# 	 {'tag': 5, 'ind': 'mcpd', 'fitness': 6}
# 	 {'tag': 6, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# Mutation in gen 3 in [8 : ocud] with mut= 0.031743985782634265. p to u
# 	 {'tag': 8, 'ind': 'ocud', 'fitness': 9}
# Mutation in gen 2 in [9 : obpd] with mut= 0.03450747610459248. c to b
# 	 {'tag': 9, 'ind': 'obpd', 'fitness': 5}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 51:
# sel inds: ['ocpd', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpd', 'ocpd', 'ocpe', 'ocpe']
# crossover between ocpd and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# Crossover failed.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 1 in [6 : icpe] with mut= 0.0023081986693841428. o to i
# 	 {'tag': 6, 'ind': 'icpe', 'fitness': 9}
# 	 {'tag': 7, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 52:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# crossover between ocpe and ocpe done.
# Crossover failed.
# Crossover failed.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# 	 {'tag': 1, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 4 in [2 : ocpe] with mut= 0.010992383876740397. e to e
# 	 {'tag': 2, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 7, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 9, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 53:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# crossover between ocpe and ocpe done.
# Crossover failed.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# Mutation in gen 2 in [1 : oqpe] with mut= 0.015912359219645178. c to q
# 	 {'tag': 1, 'ind': 'oqpe', 'fitness': 13}
# Mutation in gen 4 in [2 : ocpd] with mut= 0.037673613326372535. e to d
# 	 {'tag': 2, 'ind': 'ocpd', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 7, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 4 in [9 : ocpx] with mut= 0.009488858417552315. e to x
# 	 {'tag': 9, 'ind': 'ocpx', 'fitness': 22}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 54:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# 	 {'tag': 1, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 2, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 7, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 9, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 55:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# crossover between ocpe and ocpe done.
# Crossover failed.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# 	 {'tag': 1, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 2, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 3 in [3 : ocpe] with mut= 0.03158840313452649. p to p
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 2 in [6 : oxpe] with mut= 0.028480472025739223. c to x
# 	 {'tag': 6, 'ind': 'oxpe', 'fitness': 20}
# 	 {'tag': 7, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 9, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 3 in [10 : ocje] with mut= 0.024150616413833537. p to j
# 	 {'tag': 10, 'ind': 'ocje', 'fitness': 9}
#
# gen 56:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# crossover between ocpe and ocpe done.
# Crossover failed.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 2, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 1 in [7 : ncpe] with mut= 0.030753380744383385. o to n
# Mutation in gen 3 in [7 : ncve] with mut= 0.047900721565619864. p to v
# 	 {'tag': 7, 'ind': 'ncve', 'fitness': 10}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 3 in [9 : ocge] with mut= 0.036660339569921985. p to g
# 	 {'tag': 9, 'ind': 'ocge', 'fitness': 12}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 57:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# Crossover failed.
# Crossover failed.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# Mutation in gen 3 in [1 : ocle] with mut= 0.04708341356471246. p to l
# 	 {'tag': 1, 'ind': 'ocle', 'fitness': 7}
# 	 {'tag': 2, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 7, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 9, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 58:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# 	 {'tag': 1, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 1 in [2 : tcpe] with mut= 0.03778057893350251. o to t
# 	 {'tag': 2, 'ind': 'tcpe', 'fitness': 6}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 4 in [4 : ocpt] with mut= 0.021354950358853042. e to t
# 	 {'tag': 4, 'ind': 'ocpt', 'fitness': 18}
# Mutation in gen 1 in [5 : zcpe] with mut= 0.020377568508060162. o to z
# 	 {'tag': 5, 'ind': 'zcpe', 'fitness': 12}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 7, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 9, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 59:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# Crossover failed.
# ...
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 7, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 4 in [9 : ocpc] with mut= 0.005327686125556563. e to c
# 	 {'tag': 9, 'ind': 'ocpc', 'fitness': 5}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 71:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# crossover between ocpe and ocpe done.
# Crossover failed.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# 	 {'tag': 1, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 2, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 7, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 4 in [9 : ocpu] with mut= 0.013030445528868784. e to u
# 	 {'tag': 9, 'ind': 'ocpu', 'fitness': 19}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 72:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# crossover between ocpe and ocpe done.
# Crossover failed.
# Crossover failed.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# 	 {'tag': 1, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 2, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 4 in [4 : ocpg] with mut= 0.03883828530402478. e to g
# 	 {'tag': 4, 'ind': 'ocpg', 'fitness': 5}
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 7, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 9, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 73:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# 	 {'tag': 1, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 2, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 1 in [7 : scpe] with mut= 0.008451112113442294. o to s
# 	 {'tag': 7, 'ind': 'scpe', 'fitness': 5}
# Mutation in gen 2 in [8 : obpe] with mut= 0.01300985535479171. c to b
# 	 {'tag': 8, 'ind': 'obpe', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 74:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# Crossover failed.
# Crossover failed.
# crossover between ocpe and ocpe done.
# Mutation in gen 3 in [1 : ocbe] with mut= 0.048965688276202735. p to b
# 	 {'tag': 1, 'ind': 'ocbe', 'fitness': 17}
# 	 {'tag': 2, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 2 in [3 : oppe] with mut= 0.012779357618762699. c to p
# 	 {'tag': 3, 'ind': 'oppe', 'fitness': 12}
# Mutation in gen 2 in [4 : owpe] with mut= 0.010543487028171428. c to w
# 	 {'tag': 4, 'ind': 'owpe', 'fitness': 19}
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 3 in [6 : ocbe] with mut= 0.04149776367118452. p to b
# 	 {'tag': 6, 'ind': 'ocbe', 'fitness': 17}
# Mutation in gen 3 in [7 : ocxe] with mut= 0.010009352016400297. p to x
# 	 {'tag': 7, 'ind': 'ocxe', 'fitness': 11}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 9, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 75:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocxe', 'ocpe', 'ocpe', 'ocpe']
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocxe and ocpe done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 2, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 7, 'ind': 'ocxe', 'fitness': 11}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 3 in [9 : ocqe] with mut= 0.027833251851423824. p to q
# 	 {'tag': 9, 'ind': 'ocqe', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 76:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# Crossover failed.
# Crossover failed.
# Crossover failed.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# 	 {'tag': 1, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 2 in [2 : oqpe] with mut= 0.026793529307520103. c to q
# Mutation in gen 4 in [2 : oqps] with mut= 0.009310212554460073. e to s
# 	 {'tag': 2, 'ind': 'oqps', 'fitness': 27}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 7, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 9, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 77:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# Crossover failed.
# Crossover failed.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# 	 {'tag': 1, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 3 in [2 : ocwe] with mut= 0.03806621070667415. p to w
# 	 {'tag': 2, 'ind': 'ocwe', 'fitness': 10}
# Mutation in gen 4 in [3 : ocpz] with mut= 0.013734024165199643. e to z
# 	 {'tag': 3, 'ind': 'ocpz', 'fitness': 24}
# 	 {'tag': 4, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 7, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 2 in [8 : oipe] with mut= 0.01955035807724881. c to i
# 	 {'tag': 8, 'ind': 'oipe', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 2 in [10 : ojpe] with mut= 0.012414656511769984. c to j
# 	 {'tag': 10, 'ind': 'ojpe', 'fitness': 6}
#
# gen 78:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# 	 {'tag': 1, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 2, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 3 in [5 : ocwe] with mut= 0.008664431719813903. p to w
# 	 {'tag': 5, 'ind': 'ocwe', 'fitness': 10}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 7, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 9, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 79:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# crossover between ocpe and ocpe done.
# Crossover failed.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# 	 {'tag': 1, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 2, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 2 in [7 : orpe] with mut= 0.016817390644705554. c to r
# 	 {'tag': 7, 'ind': 'orpe', 'fitness': 14}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 9, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 80:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# crossover between ocpe and ocpe done.
# Crossover failed.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# Mutation in gen 3 in [1 : ocke] with mut= 0.04560097781536687. p to k
# 	 {'tag': 1, 'ind': 'ocke', 'fitness': 8}
# 	 {'tag': 2, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 5, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 7, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 9, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 81:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# Crossover failed.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# 	 {'tag': 1, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 4 in [2 : ocph] with mut= 0.04356351785470802. e to h
# 	 {'tag': 2, 'ind': 'ocph', 'fitness': 6}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 3 in [5 : ocle] with mut= 0.031423878024708585. p to l
# 	 {'tag': 5, 'ind': 'ocle', 'fitness': 7}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 7, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 1 in [8 : xcpe] with mut= 0.005631393089135739. o to x
# 	 {'tag': 8, 'ind': 'xcpe', 'fitness': 10}
# 	 {'tag': 9, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 82:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# Mutation in gen 4 in [1 : ocpf] with mut= 0.03511249378744641. e to f
# 	 {'tag': 1, 'ind': 'ocpf', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 1 in [5 : ycpe] with mut= 0.02191815060230784. o to y
# 	 {'tag': 5, 'ind': 'ycpe', 'fitness': 11}
# Mutation in gen 1 in [6 : xcpe] with mut= 0.008982154033106315. o to x
# 	 {'tag': 6, 'ind': 'xcpe', 'fitness': 10}
# Mutation in gen 4 in [7 : ocps] with mut= 0.004515481461325077. e to s
# 	 {'tag': 7, 'ind': 'ocps', 'fitness': 17}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 2 in [9 : okpe] with mut= 0.03716311023075758. c to k
# 	 {'tag': 9, 'ind': 'okpe', 'fitness': 7}
# Mutation in gen 1 in [10 : acpe] with mut= 0.04744953031574872. o to a
# Mutation in gen 3 in [10 : acxe] with mut= 0.03189025914468668. p to x
# 	 {'tag': 10, 'ind': 'acxe', 'fitness': 25}
#
# gen 83:
# sel inds: ['ocpe', 'ocpe', 'xcpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'ocpe']
# crossover between ocpe and ocpe done.
# crossover between xcpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# crossover between ocpe and ocpe done.
# 	 {'tag': 1, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 2, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 3, 'ind': 'xcpe', 'fitness': 10}
# Mutation in gen 2 in [4 : ompe] with mut= 0.0026143319788333175. c to m
# 	 {'tag': 4, 'ind': 'ompe', 'fitness': 9}
# Mutation in gen 2 in [5 : oepe] with mut= 0.007151216035811148. c to e
# 	 {'tag': 5, 'ind': 'oepe', 'fitness': 1}
# Mutation in gen 3 in [6 : ocre] with mut= 0.02935011073556959. p to r
# 	 {'tag': 6, 'ind': 'ocre', 'fitness': 5}
# 	 {'tag': 7, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 9, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 10, 'ind': 'ocpe', 'fitness': 3}
#
# gen 84:
# sel inds: ['ocpe', 'ocpe', 'ocpe', 'oepe', 'oepe', 'ocpe', 'ocpe', 'ocpe', 'ocpe', 'oepe']
# crossover between ocpe and ocpe done.
# crossover between ocpe and oepe done.
# crossover between oepe and ocpe done.
# crossover between ocpe and ocpe done.
# Crossover failed.
# Mutation in gen 4 in [1 : ocpg] with mut= 0.017051985788345103. e to g
# 	 {'tag': 1, 'ind': 'ocpg', 'fitness': 5}
# 	 {'tag': 2, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 4, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 5, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 4 in [7 : ocpg] with mut= 0.004759637045320897. e to g
# 	 {'tag': 7, 'ind': 'ocpg', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 9, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 1 in [10 : lepe] with mut= 0.031946530982051025. o to l
# 	 {'tag': 10, 'ind': 'lepe', 'fitness': 4}
#
# gen 85:
# sel inds: ['ocpe', 'oepe', 'ocpe', 'ocpe', 'ocpe', 'oepe', 'oepe', 'ocpe', 'oepe', 'oepe']
# Crossover failed.
# Crossover failed.
# crossover between ocpe and oepe done.
# crossover between oepe and ocpe done.
# crossover between oepe and oepe done.
# 	 {'tag': 1, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 2, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 3, 'ind': 'ocpe', 'fitness': 3}
# Mutation in gen 3 in [4 : ocde] with mut= 0.03325416120520308. p to d
# 	 {'tag': 4, 'ind': 'ocde', 'fitness': 15}
# 	 {'tag': 5, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 6, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 7, 'ind': 'ocpe', 'fitness': 3}
# 	 {'tag': 8, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'oepe', 'fitness': 1}
#
# gen 86:
# sel inds: ['oepe', 'oepe', 'oepe', 'oepe', 'oepe', 'oepe', 'oepe', 'oepe', 'oepe', 'oepe']
# crossover between oepe and oepe done.
# crossover between oepe and oepe done.
# crossover between oepe and oepe done.
# Crossover failed.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 2, 'ind': 'oepe', 'fitness': 1}
# Mutation in gen 2 in [3 : olpe] with mut= 0.04904063348365195. e to l
# 	 {'tag': 3, 'ind': 'olpe', 'fitness': 8}
# Mutation in gen 1 in [4 : depe] with mut= 0.0060008200400812894. o to d
# 	 {'tag': 4, 'ind': 'depe', 'fitness': 12}
# 	 {'tag': 5, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 6, 'ind': 'oepe', 'fitness': 1}
# Mutation in gen 1 in [7 : uepe] with mut= 0.04709004142792372. o to u
# 	 {'tag': 7, 'ind': 'uepe', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'oepe', 'fitness': 1}
# Mutation in gen 4 in [9 : oepe] with mut= 0.03371727888153275. e to e
# 	 {'tag': 9, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'oepe', 'fitness': 1}
#
# gen 87:
# sel inds: ['oepe', 'oepe', 'oepe', 'oepe', 'oepe', 'oepe', 'oepe', 'oepe', 'oepe', 'oepe']
# Crossover failed.
# Crossover failed.
# Crossover failed.
# crossover between oepe and oepe done.
# crossover between oepe and oepe done.
# Mutation in gen 2 in [1 : oype] with mut= 0.035404914755881145. e to y
# 	 {'tag': 1, 'ind': 'oype', 'fitness': 21}
# 	 {'tag': 2, 'ind': 'oepe', 'fitness': 1}
# Mutation in gen 4 in [3 : oepw] with mut= 0.024764036523195143. e to w
# 	 {'tag': 3, 'ind': 'oepw', 'fitness': 19}
# Mutation in gen 3 in [4 : oepe] with mut= 0.03184454189577435. p to p
# 	 {'tag': 4, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 5, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 6, 'ind': 'oepe', 'fitness': 1}
# Mutation in gen 1 in [7 : cepe] with mut= 0.03412172922292056. o to c
# 	 {'tag': 7, 'ind': 'cepe', 'fitness': 13}
# 	 {'tag': 8, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'oepe', 'fitness': 1}
#
# gen 88:
# sel inds: ['oepe', 'oepe', 'oepe', 'oepe', 'oepe', 'oepe', 'oepe', 'oepe', 'oepe', 'oepe']
# crossover between oepe and oepe done.
# crossover between oepe and oepe done.
# Crossover failed.
# crossover between oepe and oepe done.
# crossover between oepe and oepe done.
# 	 {'tag': 1, 'ind': 'oepe', 'fitness': 1}
# Mutation in gen 1 in [2 : pepe] with mut= 0.04704885919406332. o to p
# 	 {'tag': 2, 'ind': 'pepe', 'fitness': 0}
# 	 {'tag': 3, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 4, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 5, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 6, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 7, 'ind': 'oepe', 'fitness': 1}
# Mutation in gen 4 in [8 : oepa] with mut= 0.029230897347219842. e to a
# 	 {'tag': 8, 'ind': 'oepa', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'oepe', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'oepe', 'fitness': 1}
#
# Password found!
# Gen: 88
# Ind: 2
# Password: pepe

# %% [markdown]
# ### Algoritmo genético

# %% [markdown]
# ## Conclusão

# %% [markdown]
# ## Playground
