# %% [markdown]
# Descobrindo a senha
# ===================

# %% [markdown]
# ## Objetivo

# %% [markdown]
# Usar um algoritmo genético para descobrir uma senha.

# %% [markdown]
# ## Descrição do problema

# %% [markdown]
# Neste problema, a função objetivo deve saber a senha correta e quantificar de alguma maneira o quão perto ou longe os palpites estão da solução (veja que isso é algo que não temos no mundo real. Nenhum site irá te dizer se você está acertando ou errando seu palpite). O critério de parada deste problema é quando a senha for descoberta.

# %% [markdown]
# ## Importações

# %%
from string import printable
from funcoes import new_pop_passw, fitness_passw, tourn_sel_min, crossover_passw, mutation_passw
import random as rd

# %% [markdown]
# ## Códigos e discussão

# %% [markdown]
# ### Gerador de senha

# %%
pass_chars = printable[:-5]

# %%
def create_password(n):
    password = ""
    for i in range(n):
        password += rd.choice(pass_chars)
    return password

# %%
TAM_POP = 10
NUM_GEN = 1000
GEN_MAX = 100
PM = 0.05 # Probabilidade de mutação
PC = 0.75 # Probabilidade de cruzamento
PS = 24 # Número de caracteres da senha

TAM_CROMO = PS

PASSWORD = create_password(PS)
print("Real password: '", PASSWORD, "'", sep='')
# Out:
# Real password: '~3C&VNpVW}6rSpUthb13%'7v'

# %%
# Teste com uma senha mais simples

PASSWORD = "pepe"
pass_chars = "abcdefghijklmnopqrstuvwxyz"
TAM_CROMO = len(PASSWORD)

# %%
gen = 1
pop = new_pop_passw(TAM_POP, TAM_CROMO, pass_chars, PASSWORD)

min_fit = float('inf')

while min_fit != 0:
    print("gen ", gen, ":", sep="")
    if gen > 1:
        pop = tourn_sel_min(pop, PASSWORD)

        pop_inds = [pop[i]["ind"] for i in pop]
        p1_list = pop_inds[0::2]
        p2_list = pop_inds[1::2]
        c = 1
        for p1, p2 in zip(p1_list, p2_list):
            filho1, filho2 = crossover_passw(p1, p2, PC)
            pop[c]["ind"] = filho1
            pop[c + 1]["ind"] = filho2
            c += 2
    for i in pop:
        curr_ind = pop[i]
        if gen > 1:
            curr_ind = mutation_passw(curr_ind, pass_chars, PM)
        curr_ind["fitness"] = fitness_passw(curr_ind["ind"], PASSWORD)
        print("\t", curr_ind)
    for i in pop:
        if pop[i]['fitness'] == 0:
            best_ind = pop[i]['ind']
            best_ind_tag = pop[i]['tag']
            min_fit = 0
            print(f'\nPassword found!\nGen: {gen}\nInd: {best_ind_tag}\nPassword: {best_ind}')
    gen += 1
    print()
# Out:
# gen 1:
# 	 {'tag': 1, 'ind': 'zsyp', 'fitness': 44}
# 	 {'tag': 2, 'ind': 'lhft', 'fitness': 32}
# 	 {'tag': 3, 'ind': 'xgth', 'fitness': 17}
# 	 {'tag': 4, 'ind': 'ewby', 'fitness': 63}
# 	 {'tag': 5, 'ind': 'cure', 'fitness': 31}
# 	 {'tag': 6, 'ind': 'xhcs', 'fitness': 38}
# 	 {'tag': 7, 'ind': 'tjgq', 'fitness': 30}
# 	 {'tag': 8, 'ind': 'pgoq', 'fitness': 15}
# 	 {'tag': 9, 'ind': 'skjt', 'fitness': 30}
# 	 {'tag': 10, 'ind': 'fqtr', 'fitness': 39}
#
# gen 2:
# sel inds: ['xgth', 'xgth', 'xgth', 'tjgq', 'pgoq', 'tjgq', 'xhcs', 'xgth', 'tjgq', 'pgoq']
# crossover between xgth and xgth done.
# crossover between xgth and tjgq done.
# Crossover failed.
# Crossover failed.
# Crossover failed.
# Mutation in gen 4 in [1 : xgtz] with mut= 0.011733220144453882. h to z
# 	 {'tag': 1, 'ind': 'xgtz', 'fitness': 35}
# 	 {'tag': 2, 'ind': 'xgth', 'fitness': 17}
# Mutation in gen 4 in [3 : xggz] with mut= 0.006779993235245363. q to z
# 	 {'tag': 3, 'ind': 'xggz', 'fitness': 40}
# 	 {'tag': 4, 'ind': 'tjth', 'fitness': 16}
# 	 {'tag': 5, 'ind': 'pgoq', 'fitness': 15}
# 	 {'tag': 6, 'ind': 'tjgq', 'fitness': 30}
# 	 {'tag': 7, 'ind': 'xhcs', 'fitness': 38}
# 	 {'tag': 8, 'ind': 'xgth', 'fitness': 17}
# Mutation in gen 3 in [9 : tjnq] with mut= 0.044339120614394156. g to n
# 	 {'tag': 9, 'ind': 'tjnq', 'fitness': 23}
# 	 {'tag': 10, 'ind': 'pgoq', 'fitness': 15}
#
# gen 3:
# sel inds: ['pgoq', 'pgoq', 'xgth', 'xgth', 'pgoq', 'tjth', 'tjth', 'pgoq', 'tjth', 'xgth']
# Crossover failed.
# Crossover failed.
# Crossover failed.
# crossover between tjth and pgoq done.
# crossover between tjth and xgth done.
# 	 {'tag': 1, 'ind': 'pgoq', 'fitness': 15}
# 	 {'tag': 2, 'ind': 'pgoq', 'fitness': 15}
# 	 {'tag': 3, 'ind': 'xgth', 'fitness': 17}
# 	 {'tag': 4, 'ind': 'xgth', 'fitness': 17}
# 	 {'tag': 5, 'ind': 'pgoq', 'fitness': 15}
# 	 {'tag': 6, 'ind': 'tjth', 'fitness': 16}
# 	 {'tag': 7, 'ind': 'tjtq', 'fitness': 25}
# 	 {'tag': 8, 'ind': 'pgoh', 'fitness': 6}
# 	 {'tag': 9, 'ind': 'tgth', 'fitness': 13}
# 	 {'tag': 10, 'ind': 'xjth', 'fitness': 20}
#
# gen 4:
# sel inds: ['tgth', 'pgoh', 'tgth', 'pgoq', 'pgoq', 'pgoq', 'tgth', 'pgoh', 'pgoq', 'pgoq']
# Crossover failed.
# crossover between tgth and pgoq done.
# crossover between pgoq and pgoq done.
# Crossover failed.
# crossover between pgoq and pgoq done.
# 	 {'tag': 1, 'ind': 'tgth', 'fitness': 13}
# 	 {'tag': 2, 'ind': 'pgoh', 'fitness': 6}
# 	 {'tag': 3, 'ind': 'tgoq', 'fitness': 19}
# Mutation in gen 1 in [4 : sgth] with mut= 0.011475162846391385. p to s
# 	 {'tag': 4, 'ind': 'sgth', 'fitness': 12}
# Mutation in gen 4 in [5 : pgoq] with mut= 0.03845190922706887. q to q
# 	 {'tag': 5, 'ind': 'pgoq', 'fitness': 15}
# 	 {'tag': 6, 'ind': 'pgoq', 'fitness': 15}
# Mutation in gen 4 in [7 : tgtr] with mut= 0.048029395066711444. h to r
# 	 {'tag': 7, 'ind': 'tgtr', 'fitness': 23}
# 	 {'tag': 8, 'ind': 'pgoh', 'fitness': 6}
# 	 {'tag': 9, 'ind': 'pgoq', 'fitness': 15}
# 	 {'tag': 10, 'ind': 'pgoq', 'fitness': 15}
#
# gen 5:
# sel inds: ['sgth', 'sgth', 'pgoq', 'pgoh', 'tgth', 'pgoh', 'pgoh', 'tgth', 'sgth', 'pgoh']
# crossover between sgth and sgth done.
# crossover between pgoq and pgoh done.
# crossover between tgth and pgoh done.
# crossover between pgoh and tgth done.
# crossover between sgth and pgoh done.
# Mutation in gen 4 in [1 : sgtn] with mut= 0.000601178740683106. h to n
# 	 {'tag': 1, 'ind': 'sgtn', 'fitness': 18}
# 	 {'tag': 2, 'ind': 'sgth', 'fitness': 12}
# Mutation in gen 3 in [3 : pglh] with mut= 0.005374702187793012. o to l
# 	 {'tag': 3, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 4, 'ind': 'pgoq', 'fitness': 15}
# 	 {'tag': 5, 'ind': 'tgoh', 'fitness': 10}
# 	 {'tag': 6, 'ind': 'pgth', 'fitness': 9}
# Mutation in gen 1 in [7 : mgth] with mut= 0.02578087545399277. p to m
# 	 {'tag': 7, 'ind': 'mgth', 'fitness': 12}
# 	 {'tag': 8, 'ind': 'tgoh', 'fitness': 10}
# Mutation in gen 4 in [9 : sgoy] with mut= 0.009834470841286191. h to y
# 	 {'tag': 9, 'ind': 'sgoy', 'fitness': 26}
# 	 {'tag': 10, 'ind': 'pgth', 'fitness': 9}
#
# gen 6:
# sel inds: ['pgth', 'pgth', 'pgth', 'tgoh', 'pglh', 'pgth', 'pgth', 'pglh', 'pglh', 'pgth']
# crossover between pgth and pgth done.
# crossover between pgth and tgoh done.
# crossover between pglh and pgth done.
# crossover between pgth and pglh done.
# crossover between pglh and pgth done.
# Mutation in gen 3 in [1 : pgjh] with mut= 0.04593926039394647. t to j
# 	 {'tag': 1, 'ind': 'pgjh', 'fitness': 11}
# 	 {'tag': 2, 'ind': 'pgth', 'fitness': 9}
# Mutation in gen 2 in [3 : pjth] with mut= 0.027444409630052236. g to j
# 	 {'tag': 3, 'ind': 'pjth', 'fitness': 12}
# 	 {'tag': 4, 'ind': 'tgoh', 'fitness': 10}
# 	 {'tag': 5, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 6, 'ind': 'pglh', 'fitness': 9}
# Mutation in gen 1 in [7 : lglh] with mut= 0.04120113298262107. p to l
# 	 {'tag': 7, 'ind': 'lglh', 'fitness': 13}
# 	 {'tag': 8, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 9, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 10, 'ind': 'pglh', 'fitness': 9}
#
# gen 7:
# sel inds: ['pgth', 'pgth', 'tgoh', 'pgth', 'pgth', 'pgth', 'pglh', 'pgth', 'pgth', 'pglh']
# Crossover failed.
# crossover between tgoh and pgth done.
# crossover between pgth and pgth done.
# Crossover failed.
# crossover between pgth and pglh done.
# 	 {'tag': 1, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 2, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 3, 'ind': 'tgoh', 'fitness': 10}
# 	 {'tag': 4, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 5, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 6, 'ind': 'pgth', 'fitness': 9}
# Mutation in gen 1 in [7 : iglh] with mut= 0.04153849854185443. p to i
# 	 {'tag': 7, 'ind': 'iglh', 'fitness': 16}
# 	 {'tag': 8, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 9, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 10, 'ind': 'pgth', 'fitness': 9}
#
# gen 8:
# sel inds: ['pglh', 'pgth', 'pgth', 'pgth', 'pgth', 'pglh', 'pglh', 'pgth', 'pgth', 'pgth']
# crossover between pglh and pgth done.
# Crossover failed.
# crossover between pgth and pglh done.
# Crossover failed.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 2, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 3, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 4, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 5, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 6, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 7, 'ind': 'pglh', 'fitness': 9}
# Mutation in gen 2 in [8 : plth] with mut= 0.04553229128969172. g to l
# 	 {'tag': 8, 'ind': 'plth', 'fitness': 14}
# 	 {'tag': 9, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 10, 'ind': 'pgth', 'fitness': 9}
#
# gen 9:
# sel inds: ['pgth', 'pgth', 'pgth', 'pglh', 'pgth', 'pgth', 'pgth', 'pglh', 'pgth', 'pgth']
# crossover between pgth and pgth done.
# crossover between pgth and pglh done.
# crossover between pgth and pgth done.
# Crossover failed.
# crossover between pgth and pgth done.
# 	 {'tag': 1, 'ind': 'pgth', 'fitness': 9}
# Mutation in gen 3 in [2 : pgch] with mut= 0.014232618188964374. t to c
# 	 {'tag': 2, 'ind': 'pgch', 'fitness': 18}
# 	 {'tag': 3, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 4, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 5, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 6, 'ind': 'pgth', 'fitness': 9}
# Mutation in gen 3 in [7 : pgah] with mut= 0.0047512543065668655. t to a
# 	 {'tag': 7, 'ind': 'pgah', 'fitness': 20}
# 	 {'tag': 8, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 9, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 10, 'ind': 'pgth', 'fitness': 9}
#
# gen 10:
# sel inds: ['pgth', 'pglh', 'pgth', 'pglh', 'pgth', 'pglh', 'pglh', 'pgth', 'pgth', 'pgth']
# crossover between pgth and pglh done.
# crossover between pgth and pglh done.
# crossover between pgth and pglh done.
# crossover between pglh and pgth done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'pgth', 'fitness': 9}
# Mutation in gen 3 in [2 : pggh] with mut= 0.021757232751607458. l to g
# 	 {'tag': 2, 'ind': 'pggh', 'fitness': 14}
# 	 {'tag': 3, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 4, 'ind': 'pgth', 'fitness': 9}
# Mutation in gen 1 in [5 : jgth] with mut= 0.034465397369652706. p to j
# 	 {'tag': 5, 'ind': 'jgth', 'fitness': 15}
# 	 {'tag': 6, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 7, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 8, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 9, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 10, 'ind': 'pgth', 'fitness': 9}
#
# gen 11:
# sel inds: ['pgth', 'pglh', 'pglh', 'pgth', 'pgth', 'pgth', 'pgth', 'pgth', 'pgth', 'pglh']
# crossover between pgth and pglh done.
# Crossover failed.
# Crossover failed.
# Crossover failed.
# crossover between pgth and pglh done.
# 	 {'tag': 1, 'ind': 'pglh', 'fitness': 9}
# Mutation in gen 4 in [2 : pgtv] with mut= 0.023829229623287262. h to v
# 	 {'tag': 2, 'ind': 'pgtv', 'fitness': 23}
# 	 {'tag': 3, 'ind': 'pglh', 'fitness': 9}
# Mutation in gen 1 in [4 : dgth] with mut= 0.04721240354895806. p to d
# 	 {'tag': 4, 'ind': 'dgth', 'fitness': 21}
# 	 {'tag': 5, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 6, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 7, 'ind': 'pgth', 'fitness': 9}
# Mutation in gen 2 in [8 : pbth] with mut= 0.017456443723637638. g to b
# 	 {'tag': 8, 'ind': 'pbth', 'fitness': 10}
# 	 {'tag': 9, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 10, 'ind': 'pglh', 'fitness': 9}
#
# gen 12:
# sel inds: ['pglh', 'pglh', 'pglh', 'pglh', 'pglh', 'pglh', 'pglh', 'pglh', 'pgth', 'pgth']
# crossover between pglh and pglh done.
# crossover between pglh and pglh done.
# crossover between pglh and pglh done.
# crossover between pglh and pglh done.
# crossover between pgth and pgth done.
# 	 {'tag': 1, 'ind': 'pglh', 'fitness': 9}
# Mutation in gen 2 in [2 : pzlh] with mut= 0.002481209744459867. g to z
# 	 {'tag': 2, 'ind': 'pzlh', 'fitness': 28}
# Mutation in gen 1 in [3 : nglh] with mut= 0.006159833472103915. p to n
# 	 {'tag': 3, 'ind': 'nglh', 'fitness': 11}
# 	 {'tag': 4, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 5, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 6, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 7, 'ind': 'pglh', 'fitness': 9}
# Mutation in gen 4 in [8 : pgls] with mut= 0.005991972179887228. h to s
# 	 {'tag': 8, 'ind': 'pgls', 'fitness': 20}
# 	 {'tag': 9, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 10, 'ind': 'pgth', 'fitness': 9}
#
# gen 13:
# sel inds: ['pglh', 'pglh', 'pgth', 'pglh', 'pglh', 'pgth', 'pglh', 'pgth', 'pgth', 'pglh']
# crossover between pglh and pglh done.
# crossover between pgth and pglh done.
# crossover between pglh and pgth done.
# crossover between pglh and pgth done.
# crossover between pgth and pglh done.
# 	 {'tag': 1, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 2, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 3, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 4, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 5, 'ind': 'pgth', 'fitness': 9}
# 	 {'tag': 6, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 7, 'ind': 'pgth', 'fitness': 9}
# Mutation in gen 3 in [8 : pggh] with mut= 0.0006343832951914985. l to g
# 	 {'tag': 8, 'ind': 'pggh', 'fitness': 14}
# Mutation in gen 3 in [9 : pgvh] with mut= 0.028560075492018888. l to v
# 	 {'tag': 9, 'ind': 'pgvh', 'fitness': 11}
# 	 {'tag': 10, 'ind': 'pgth', 'fitness': 9}
#
# gen 14:
# sel inds: ['pglh', 'pglh', 'pglh', 'pglh', 'pglh', 'pglh', 'pglh', 'pglh', 'pglh', 'pglh']
# Crossover failed.
# crossover between pglh and pglh done.
# crossover between pglh and pglh done.
# Crossover failed.
# crossover between pglh and pglh done.
# 	 {'tag': 1, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 2, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 3, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 4, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 5, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 6, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 7, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 8, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 9, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 10, 'ind': 'pglh', 'fitness': 9}
#
# gen 15:
# sel inds: ['pglh', 'pglh', 'pglh', 'pglh', 'pglh', 'pglh', 'pglh', 'pglh', 'pglh', 'pglh']
# crossover between pglh and pglh done.
# crossover between pglh and pglh done.
# crossover between pglh and pglh done.
# Crossover failed.
# crossover between pglh and pglh done.
# 	 {'tag': 1, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 2, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 3, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 4, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 5, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 6, 'ind': 'pglh', 'fitness': 9}
# Mutation in gen 1 in [7 : aglh] with mut= 0.024044483978363007. p to a
# Mutation in gen 4 in [7 : agli] with mut= 0.010941643991587258. h to i
# 	 {'tag': 7, 'ind': 'agli', 'fitness': 25}
# 	 {'tag': 8, 'ind': 'pglh', 'fitness': 9}
# Mutation in gen 4 in [9 : pglc] with mut= 0.002584703829894841. h to c
# 	 {'tag': 9, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 10, 'ind': 'pglh', 'fitness': 9}
#
# gen 16:
# sel inds: ['pglh', 'pglh', 'pglh', 'pglc', 'pglh', 'pglh', 'pglh', 'pglh', 'pglh', 'pglh']
# crossover between pglh and pglh done.
# Crossover failed.
# crossover between pglh and pglh done.
# crossover between pglh and pglh done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 2, 'ind': 'pglh', 'fitness': 9}
# Mutation in gen 1 in [3 : yglh] with mut= 0.04085403124227016. p to y
# 	 {'tag': 3, 'ind': 'yglh', 'fitness': 18}
# 	 {'tag': 4, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 5, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 6, 'ind': 'pglh', 'fitness': 9}
# Mutation in gen 3 in [7 : pgyh] with mut= 0.035152178629693775. l to y
# 	 {'tag': 7, 'ind': 'pgyh', 'fitness': 14}
# 	 {'tag': 8, 'ind': 'pglh', 'fitness': 9}
# Mutation in gen 3 in [9 : pgvh] with mut= 0.011388289239670168. l to v
# 	 {'tag': 9, 'ind': 'pgvh', 'fitness': 11}
# Mutation in gen 3 in [10 : pgth] with mut= 0.045932552253481806. l to t
# 	 {'tag': 10, 'ind': 'pgth', 'fitness': 9}
#
# gen 17:
# sel inds: ['pglc', 'pglc', 'pglh', 'pglc', 'pglc', 'pglh', 'pglc', 'pglh', 'pglh', 'pglh']
# crossover between pglc and pglc done.
# crossover between pglh and pglc done.
# Crossover failed.
# crossover between pglc and pglh done.
# crossover between pglh and pglh done.
# Mutation in gen 4 in [1 : pglz] with mut= 0.006119158832411209. c to z
# 	 {'tag': 1, 'ind': 'pglz', 'fitness': 27}
# 	 {'tag': 2, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 3, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 4, 'ind': 'pglh', 'fitness': 9}
# Mutation in gen 4 in [5 : pglh] with mut= 0.0035223993218923555. c to h
# 	 {'tag': 5, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 6, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 7, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 8, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 9, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 10, 'ind': 'pglh', 'fitness': 9}
#
# gen 18:
# sel inds: ['pglh', 'pglh', 'pglh', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc']
# crossover between pglh and pglh done.
# crossover between pglh and pglc done.
# Crossover failed.
# crossover between pglc and pglc done.
# crossover between pglc and pglc done.
# 	 {'tag': 1, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 2, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 3, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 4, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 5, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 6, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 7, 'ind': 'pglc', 'fitness': 8}
# Mutation in gen 2 in [8 : phlc] with mut= 0.008968123435124653. g to h
# 	 {'tag': 8, 'ind': 'phlc', 'fitness': 9}
# 	 {'tag': 9, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 10, 'ind': 'pglc', 'fitness': 8}
#
# gen 19:
# sel inds: ['pglh', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc']
# Crossover failed.
# crossover between pglc and pglc done.
# crossover between pglc and pglc done.
# crossover between pglc and pglc done.
# crossover between pglc and pglc done.
# 	 {'tag': 1, 'ind': 'pglh', 'fitness': 9}
# 	 {'tag': 2, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 3, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 4, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 5, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 6, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 7, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 8, 'ind': 'pglc', 'fitness': 8}
# Mutation in gen 1 in [9 : yglc] with mut= 0.0017474692702467154. p to y
# 	 {'tag': 9, 'ind': 'yglc', 'fitness': 17}
# 	 {'tag': 10, 'ind': 'pglc', 'fitness': 8}
#
# gen 20:
# sel inds: ['pglc', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc']
# crossover between pglc and pglc done.
# Crossover failed.
# crossover between pglc and pglc done.
# crossover between pglc and pglc done.
# crossover between pglc and pglc done.
# 	 {'tag': 1, 'ind': 'pglc', 'fitness': 8}
# Mutation in gen 4 in [2 : pglz] with mut= 0.007253288476331998. c to z
# 	 {'tag': 2, 'ind': 'pglz', 'fitness': 27}
# 	 {'tag': 3, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 4, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 5, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 6, 'ind': 'pglc', 'fitness': 8}
# Mutation in gen 4 in [7 : pgll] with mut= 0.03178475748355647. c to l
# 	 {'tag': 7, 'ind': 'pgll', 'fitness': 13}
# 	 {'tag': 8, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 9, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 10, 'ind': 'pglc', 'fitness': 8}
#
# gen 21:
# sel inds: ['pglc', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc', 'pglc']
# crossover between pglc and pglc done.
# crossover between pglc and pglc done.
# crossover between pglc and pglc done.
# crossover between pglc and pglc done.
# crossover between pglc and pglc done.
# Mutation in gen 2 in [1 : pglc] with mut= 0.04774249685698129. g to g
# 	 {'tag': 1, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 2, 'ind': 'pglc', 'fitness': 8}
# Mutation in gen 4 in [3 : pglp] with mut= 0.04010685206822473. c to p
# 	 {'tag': 3, 'ind': 'pglp', 'fitness': 17}
# 	 {'tag': 4, 'ind': 'pglc', 'fitness': 8}
# Mutation in gen 3 in [5 : pgnc] with mut= 0.0213668269999846. l to n
# 	 {'tag': 5, 'ind': 'pgnc', 'fitness': 6}
# Mutation in gen 4 in [6 : pglr] with mut= 0.015123020207490234. c to r
# 	 {'tag': 6, 'ind': 'pglr', 'fitness': 19}
# 	 {'tag': 7, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 8, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 9, 'ind': 'pglc', 'fitness': 8}
# Mutation in gen 2 in [10 : pdlc] with mut= 0.03874348977443487. g to d
# 	 {'tag': 10, 'ind': 'pdlc', 'fitness': 7}
#
# gen 22:
# sel inds: ['pdlc', 'pglc', 'pglc', 'pglc', 'pdlc', 'pdlc', 'pgnc', 'pgnc', 'pglc', 'pdlc']
# crossover between pdlc and pglc done.
# Crossover failed.
# crossover between pdlc and pdlc done.
# crossover between pgnc and pgnc done.
# crossover between pglc and pdlc done.
# Mutation in gen 3 in [1 : pgec] with mut= 0.04922845398825748. l to e
# 	 {'tag': 1, 'ind': 'pgec', 'fitness': 15}
# 	 {'tag': 2, 'ind': 'pdlc', 'fitness': 7}
# 	 {'tag': 3, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 4, 'ind': 'pglc', 'fitness': 8}
# Mutation in gen 4 in [5 : pdlc] with mut= 0.04963848104633828. c to c
# 	 {'tag': 5, 'ind': 'pdlc', 'fitness': 7}
# 	 {'tag': 6, 'ind': 'pdlc', 'fitness': 7}
# 	 {'tag': 7, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 8, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 9, 'ind': 'pdlc', 'fitness': 7}
# Mutation in gen 2 in [10 : pilc] with mut= 0.010198166572009226. g to i
# 	 {'tag': 10, 'ind': 'pilc', 'fitness': 10}
#
# gen 23:
# sel inds: ['pdlc', 'pgnc', 'pdlc', 'pdlc', 'pgnc', 'pdlc', 'pglc', 'pglc', 'pdlc', 'pgnc']
# crossover between pdlc and pgnc done.
# crossover between pdlc and pdlc done.
# crossover between pgnc and pdlc done.
# crossover between pglc and pglc done.
# crossover between pdlc and pgnc done.
# 	 {'tag': 1, 'ind': 'pdlc', 'fitness': 7}
# 	 {'tag': 2, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 3, 'ind': 'pdlc', 'fitness': 7}
# 	 {'tag': 4, 'ind': 'pdlc', 'fitness': 7}
# 	 {'tag': 5, 'ind': 'pdlc', 'fitness': 7}
# Mutation in gen 4 in [6 : pgnl] with mut= 0.03758568850450683. c to l
# 	 {'tag': 6, 'ind': 'pgnl', 'fitness': 11}
# 	 {'tag': 7, 'ind': 'pglc', 'fitness': 8}
# Mutation in gen 1 in [8 : wglc] with mut= 0.044143775638017746. p to w
# 	 {'tag': 8, 'ind': 'wglc', 'fitness': 15}
# 	 {'tag': 9, 'ind': 'pdlc', 'fitness': 7}
# 	 {'tag': 10, 'ind': 'pgnc', 'fitness': 6}
#
# gen 24:
# sel inds: ['pdlc', 'pdlc', 'pdlc', 'pgnc', 'pgnc', 'pgnc', 'pgnc', 'pdlc', 'pdlc', 'pgnc']
# crossover between pdlc and pdlc done.
# crossover between pdlc and pgnc done.
# crossover between pgnc and pgnc done.
# crossover between pgnc and pdlc done.
# crossover between pdlc and pgnc done.
# 	 {'tag': 1, 'ind': 'pdlc', 'fitness': 7}
# 	 {'tag': 2, 'ind': 'pdlc', 'fitness': 7}
# 	 {'tag': 3, 'ind': 'pgnc', 'fitness': 6}
# Mutation in gen 4 in [4 : pdlh] with mut= 0.03067524656357068. c to h
# 	 {'tag': 4, 'ind': 'pdlh', 'fitness': 8}
# 	 {'tag': 5, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 6, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 7, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 8, 'ind': 'pdlc', 'fitness': 7}
# 	 {'tag': 9, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 10, 'ind': 'pdlc', 'fitness': 7}
#
# gen 25:
# sel inds: ['pgnc', 'pgnc', 'pgnc', 'pgnc', 'pgnc', 'pgnc', 'pgnc', 'pgnc', 'pgnc', 'pdlc']
# crossover between pgnc and pgnc done.
# Crossover failed.
# crossover between pgnc and pgnc done.
# Crossover failed.
# crossover between pgnc and pdlc done.
# 	 {'tag': 1, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 2, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 3, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 4, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 5, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 6, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 7, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 8, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 9, 'ind': 'pglc', 'fitness': 8}
# 	 {'tag': 10, 'ind': 'pdnc', 'fitness': 5}
#
# gen 26:
# sel inds: ['pgnc', 'pgnc', 'pgnc', 'pdnc', 'pgnc', 'pgnc', 'pgnc', 'pgnc', 'pgnc', 'pgnc']
# Crossover failed.
# crossover between pgnc and pdnc done.
# crossover between pgnc and pgnc done.
# crossover between pgnc and pgnc done.
# crossover between pgnc and pgnc done.
# 	 {'tag': 1, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 2, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 3, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 4, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 5, 'ind': 'pgnc', 'fitness': 6}
# Mutation in gen 1 in [6 : qgnc] with mut= 0.020746811873919357. p to q
# 	 {'tag': 6, 'ind': 'qgnc', 'fitness': 7}
# 	 {'tag': 7, 'ind': 'pgnc', 'fitness': 6}
# Mutation in gen 2 in [8 : pync] with mut= 0.03301380667124121. g to y
# 	 {'tag': 8, 'ind': 'pync', 'fitness': 24}
# 	 {'tag': 9, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 10, 'ind': 'pgnc', 'fitness': 6}
#
# gen 27:
# sel inds: ['pdnc', 'pgnc', 'pdnc', 'pgnc', 'pgnc', 'pgnc', 'pdnc', 'pgnc', 'pgnc', 'pgnc']
# crossover between pdnc and pgnc done.
# crossover between pdnc and pgnc done.
# Crossover failed.
# Crossover failed.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 2, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 3, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 4, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 5, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 6, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 7, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 9, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 10, 'ind': 'pgnc', 'fitness': 6}
#
# gen 28:
# sel inds: ['pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pgnc', 'pdnc']
# crossover between pdnc and pdnc done.
# crossover between pdnc and pdnc done.
# crossover between pdnc and pdnc done.
# Crossover failed.
# crossover between pgnc and pdnc done.
# Mutation in gen 4 in [1 : pdnl] with mut= 0.024896147903420984. c to l
# 	 {'tag': 1, 'ind': 'pdnl', 'fitness': 10}
# 	 {'tag': 2, 'ind': 'pdnc', 'fitness': 5}
# Mutation in gen 2 in [3 : pvnc] with mut= 0.01976503214820735. d to v
# 	 {'tag': 3, 'ind': 'pvnc', 'fitness': 21}
# 	 {'tag': 4, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 5, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 6, 'ind': 'pdnc', 'fitness': 5}
# Mutation in gen 1 in [7 : sdnc] with mut= 0.008284581781199285. p to s
# 	 {'tag': 7, 'ind': 'sdnc', 'fitness': 8}
# 	 {'tag': 8, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'pgnc', 'fitness': 6}
# 	 {'tag': 10, 'ind': 'pdnc', 'fitness': 5}
#
# gen 29:
# sel inds: ['pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc']
# crossover between pdnc and pdnc done.
# crossover between pdnc and pdnc done.
# crossover between pdnc and pdnc done.
# crossover between pdnc and pdnc done.
# crossover between pdnc and pdnc done.
# Mutation in gen 4 in [1 : pdnx] with mut= 0.04730525111073114. c to x
# 	 {'tag': 1, 'ind': 'pdnx', 'fitness': 22}
# 	 {'tag': 2, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 3, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 4, 'ind': 'pdnc', 'fitness': 5}
# Mutation in gen 4 in [5 : pdnw] with mut= 0.03035709293922384. c to w
# 	 {'tag': 5, 'ind': 'pdnw', 'fitness': 21}
# 	 {'tag': 6, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 7, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 10, 'ind': 'pdnc', 'fitness': 5}
#
# gen 30:
# sel inds: ['pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc']
# crossover between pdnc and pdnc done.
# Crossover failed.
# crossover between pdnc and pdnc done.
# crossover between pdnc and pdnc done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 2, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 3, 'ind': 'pdnc', 'fitness': 5}
# Mutation in gen 2 in [4 : pknc] with mut= 0.023884754073617676. d to k
# Mutation in gen 3 in [4 : pkuc] with mut= 0.0010489936866823202. n to u
# 	 {'tag': 4, 'ind': 'pkuc', 'fitness': 13}
# Mutation in gen 2 in [5 : pnnc] with mut= 0.045496821248941055. d to n
# 	 {'tag': 5, 'ind': 'pnnc', 'fitness': 13}
# 	 {'tag': 6, 'ind': 'pdnc', 'fitness': 5}
# Mutation in gen 2 in [7 : pinc] with mut= 0.038934579631786814. d to i
# 	 {'tag': 7, 'ind': 'pinc', 'fitness': 8}
# 	 {'tag': 8, 'ind': 'pdnc', 'fitness': 5}
# Mutation in gen 1 in [9 : ednc] with mut= 0.043186921740939965. p to e
# 	 {'tag': 9, 'ind': 'ednc', 'fitness': 16}
# 	 {'tag': 10, 'ind': 'pdnc', 'fitness': 5}
#
# gen 31:
# sel inds: ['pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pinc', 'pdnc', 'pdnc', 'pdnc']
# crossover between pdnc and pdnc done.
# crossover between pdnc and pdnc done.
# crossover between pdnc and pdnc done.
# crossover between pinc and pdnc done.
# crossover between pdnc and pdnc done.
# Mutation in gen 3 in [1 : pddc] with mut= 0.04224821270329415. n to d
# 	 {'tag': 1, 'ind': 'pddc', 'fitness': 15}
# 	 {'tag': 2, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 3, 'ind': 'pdnc', 'fitness': 5}
# Mutation in gen 3 in [4 : pdec] with mut= 0.04662187137391549. n to e
# 	 {'tag': 4, 'ind': 'pdec', 'fitness': 14}
# 	 {'tag': 5, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 6, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 7, 'ind': 'pinc', 'fitness': 8}
# 	 {'tag': 8, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 10, 'ind': 'pdnc', 'fitness': 5}
#
# gen 32:
# sel inds: ['pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc']
# crossover between pdnc and pdnc done.
# crossover between pdnc and pdnc done.
# crossover between pdnc and pdnc done.
# crossover between pdnc and pdnc done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 2, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 3, 'ind': 'pdnc', 'fitness': 5}
# Mutation in gen 1 in [4 : adnc] with mut= 0.02653639849983136. p to a
# Mutation in gen 3 in [4 : addc] with mut= 0.03383920406991214. n to d
# 	 {'tag': 4, 'ind': 'addc', 'fitness': 30}
# 	 {'tag': 5, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 6, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 7, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 10, 'ind': 'pdnc', 'fitness': 5}
#
# gen 33:
# sel inds: ['pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc']
# crossover between pdnc and pdnc done.
# Crossover failed.
# Crossover failed.
# crossover between pdnc and pdnc done.
# crossover between pdnc and pdnc done.
# 	 {'tag': 1, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 2, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 3, 'ind': 'pdnc', 'fitness': 5}
# Mutation in gen 1 in [4 : qdnc] with mut= 0.03579916966742169. p to q
# Mutation in gen 3 in [4 : qdoc] with mut= 0.008976551920208076. n to o
# 	 {'tag': 4, 'ind': 'qdoc', 'fitness': 5}
# Mutation in gen 2 in [5 : psnc] with mut= 0.0274313253411802. d to s
# 	 {'tag': 5, 'ind': 'psnc', 'fitness': 18}
# Mutation in gen 4 in [6 : pdnt] with mut= 0.01601028601126997. c to t
# 	 {'tag': 6, 'ind': 'pdnt', 'fitness': 18}
# 	 {'tag': 7, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 10, 'ind': 'pdnc', 'fitness': 5}
#
# gen 34:
# sel inds: ['pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc']
# crossover between pdnc and pdnc done.
# crossover between pdnc and pdnc done.
# crossover between pdnc and pdnc done.
# Crossover failed.
# crossover between pdnc and pdnc done.
# 	 {'tag': 1, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 2, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 3, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 4, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 5, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 6, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 7, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'pdnc', 'fitness': 5}
# Mutation in gen 2 in [9 : ponc] with mut= 0.015819140393617426. d to o
# 	 {'tag': 9, 'ind': 'ponc', 'fitness': 14}
# 	 {'tag': 10, 'ind': 'pdnc', 'fitness': 5}
#
# gen 35:
# sel inds: ['pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc', 'pdnc']
# crossover between pdnc and pdnc done.
# Crossover failed.
# crossover between pdnc and pdnc done.
# crossover between pdnc and pdnc done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'pdnc', 'fitness': 5}
# Mutation in gen 4 in [2 : pdnb] with mut= 0.012273598561323151. c to b
# 	 {'tag': 2, 'ind': 'pdnb', 'fitness': 6}
# 	 {'tag': 3, 'ind': 'pdnc', 'fitness': 5}
# Mutation in gen 4 in [4 : pdnh] with mut= 0.025385885071178338. c to h
# 	 {'tag': 4, 'ind': 'pdnh', 'fitness': 6}
# Mutation in gen 3 in [5 : pdsc] with mut= 0.018911417070045178. n to s
# 	 {'tag': 5, 'ind': 'pdsc', 'fitness': 6}
# Mutation in gen 2 in [6 : penc] with mut= 0.03490439828945757. d to e
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'pdnc', 'fitness': 5}
# Mutation in gen 3 in [9 : pdcc] with mut= 0.04078422188170783. n to c
# 	 {'tag': 9, 'ind': 'pdcc', 'fitness': 16}
# 	 {'tag': 10, 'ind': 'pdnc', 'fitness': 5}
#
# gen 36:
# sel inds: ['penc', 'penc', 'pdnc', 'pdnc', 'pdnc', 'penc', 'pdnc', 'pdnc', 'pdnc', 'pdnc']
# crossover between penc and penc done.
# crossover between pdnc and pdnc done.
# crossover between pdnc and penc done.
# crossover between pdnc and pdnc done.
# crossover between pdnc and pdnc done.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 4, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 5, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 2 in [7 : ppnc] with mut= 0.028374008909547332. d to p
# 	 {'tag': 7, 'ind': 'ppnc', 'fitness': 15}
# 	 {'tag': 8, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 10, 'ind': 'pdnc', 'fitness': 5}
#
# gen 37:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'pdnc', 'pdnc', 'pdnc']
# crossover between penc and penc done.
# Crossover failed.
# Crossover failed.
# Crossover failed.
# Crossover failed.
# Mutation in gen 2 in [1 : pqnc] with mut= 0.0070583812059011874. e to q
# 	 {'tag': 1, 'ind': 'pqnc', 'fitness': 16}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 1 in [6 : wenc] with mut= 0.025866738034112435. p to w
# 	 {'tag': 6, 'ind': 'wenc', 'fitness': 11}
# 	 {'tag': 7, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 10, 'ind': 'pdnc', 'fitness': 5}
#
# gen 38:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# crossover between penc and penc done.
# Crossover failed.
# Crossover failed.
# crossover between penc and penc done.
# crossover between penc and penc done.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'penc', 'fitness': 4}
#
# gen 39:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# crossover between penc and penc done.
# Crossover failed.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 3 in [7 : pemc] with mut= 0.0404691173379258. n to m
# 	 {'tag': 7, 'ind': 'pemc', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'penc', 'fitness': 4}
#
# gen 40:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# Crossover failed.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 2 in [10 : pxnc] with mut= 0.0029228581441756996. e to x
# 	 {'tag': 10, 'ind': 'pxnc', 'fitness': 23}
#
# gen 41:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 2 in [3 : pdnc] with mut= 0.01964777119775607. e to d
# 	 {'tag': 3, 'ind': 'pdnc', 'fitness': 5}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 1 in [6 : genc] with mut= 0.008953147715560661. p to g
# 	 {'tag': 6, 'ind': 'genc', 'fitness': 13}
# 	 {'tag': 7, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 2 in [9 : penc] with mut= 0.04795696744027955. e to e
# 	 {'tag': 9, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'penc', 'fitness': 4}
#
# gen 42:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 1 in [4 : kenc] with mut= 0.048898592431380394. p to k
# Mutation in gen 4 in [4 : keng] with mut= 0.043086436277297024. c to g
# 	 {'tag': 4, 'ind': 'keng', 'fitness': 9}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 2 in [7 : plnc] with mut= 0.024917596872314318. e to l
# 	 {'tag': 7, 'ind': 'plnc', 'fitness': 11}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'penc', 'fitness': 4}
#
# gen 43:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 4 in [5 : penz] with mut= 0.01890391101450417. c to z
# 	 {'tag': 5, 'ind': 'penz', 'fitness': 23}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'penc', 'fitness': 4}
#
# gen 44:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# crossover between penc and penc done.
# Crossover failed.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 3 in [6 : pexc] with mut= 0.025272119269101667. n to x
# 	 {'tag': 6, 'ind': 'pexc', 'fitness': 10}
# 	 {'tag': 7, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 2 in [8 : pvnc] with mut= 0.009619774270314685. e to v
# 	 {'tag': 8, 'ind': 'pvnc', 'fitness': 21}
# 	 {'tag': 9, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'penc', 'fitness': 4}
#
# gen 45:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 4 in [5 : peno] with mut= 0.04692251041219864. c to o
# 	 {'tag': 5, 'ind': 'peno', 'fitness': 12}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'penc', 'fitness': 4}
#
# gen 46:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# Mutation in gen 2 in [1 : ppnc] with mut= 0.002009000234775904. e to p
# 	 {'tag': 1, 'ind': 'ppnc', 'fitness': 15}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 4 in [10 : penl] with mut= 0.018020374543577633. c to l
# 	 {'tag': 10, 'ind': 'penl', 'fitness': 9}
#
# gen 47:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 4 in [10 : penv] with mut= 0.03711333269581507. c to v
# 	 {'tag': 10, 'ind': 'penv', 'fitness': 19}
#
# gen 48:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# Crossover failed.
# Crossover failed.
# crossover between penc and penc done.
# Crossover failed.
# crossover between penc and penc done.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 3 in [7 : pevc] with mut= 0.024614484884394106. n to v
# 	 {'tag': 7, 'ind': 'pevc', 'fitness': 8}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'penc', 'fitness': 4}
#
# gen 49:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# crossover between penc and penc done.
# Crossover failed.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 4 in [9 : penx] with mut= 0.014645430610301657. c to x
# 	 {'tag': 9, 'ind': 'penx', 'fitness': 21}
# Mutation in gen 2 in [10 : pvnc] with mut= 0.02641807496529147. e to v
# 	 {'tag': 10, 'ind': 'pvnc', 'fitness': 21}
#
# gen 50:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# Crossover failed.
# crossover between penc and penc done.
# crossover between penc and penc done.
# Crossover failed.
# crossover between penc and penc done.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'penc', 'fitness': 4}
#
# gen 51:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 2 in [4 : pqnc] with mut= 0.03558289558543348. e to q
# 	 {'tag': 4, 'ind': 'pqnc', 'fitness': 16}
# Mutation in gen 4 in [5 : peno] with mut= 0.04949915449169251. c to o
# 	 {'tag': 5, 'ind': 'peno', 'fitness': 12}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 3 in [8 : pehc] with mut= 0.04066239869624644. n to h
# 	 {'tag': 8, 'ind': 'pehc', 'fitness': 10}
# 	 {'tag': 9, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 2 in [10 : pnnc] with mut= 0.03367520773569688. e to n
# 	 {'tag': 10, 'ind': 'pnnc', 'fitness': 13}
#
# gen 52:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 2 in [3 : penc] with mut= 0.017031792906046284. e to e
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 3 in [10 : peuc] with mut= 0.01654663062178452. n to u
# 	 {'tag': 10, 'ind': 'peuc', 'fitness': 7}
#
# gen 53:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# Crossover failed.
# crossover between penc and penc done.
# crossover between penc and penc done.
# Crossover failed.
# crossover between penc and penc done.
# Mutation in gen 2 in [1 : pcnc] with mut= 0.045950268278222905. e to c
# 	 {'tag': 1, 'ind': 'pcnc', 'fitness': 6}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 3 in [3 : pekc] with mut= 0.01990081745195882. n to k
# 	 {'tag': 3, 'ind': 'pekc', 'fitness': 7}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 4 in [9 : peny] with mut= 0.042020449470182575. c to y
# 	 {'tag': 9, 'ind': 'peny', 'fitness': 22}
# 	 {'tag': 10, 'ind': 'penc', 'fitness': 4}
#
# gen 54:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 1 in [9 : ienc] with mut= 0.04120154296155254. p to i
# 	 {'tag': 9, 'ind': 'ienc', 'fitness': 11}
# Mutation in gen 4 in [10 : penh] with mut= 0.010780399029506227. c to h
# 	 {'tag': 10, 'ind': 'penh', 'fitness': 5}
#
# gen 55:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 1 in [3 : qenc] with mut= 0.029734043169613478. p to q
# 	 {'tag': 3, 'ind': 'qenc', 'fitness': 5}
# Mutation in gen 1 in [4 : penc] with mut= 0.02505762889353247. p to p
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 1 in [5 : zenc] with mut= 0.0018746320547378126. p to z
# 	 {'tag': 5, 'ind': 'zenc', 'fitness': 14}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 4 in [7 : penn] with mut= 0.0029204623739705893. c to n
# 	 {'tag': 7, 'ind': 'penn', 'fitness': 11}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'penc', 'fitness': 4}
#
# gen 56:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# crossover between penc and penc done.
# Crossover failed.
# crossover between penc and penc done.
# Crossover failed.
# crossover between penc and penc done.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 4 in [7 : penm] with mut= 0.015320228852749196. c to m
# 	 {'tag': 7, 'ind': 'penm', 'fitness': 10}
# Mutation in gen 1 in [8 : penc] with mut= 0.003402724184415895. p to p
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 2 in [10 : pdnc] with mut= 0.035331438699804485. e to d
# 	 {'tag': 10, 'ind': 'pdnc', 'fitness': 5}
#
# gen 57:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# crossover between penc and penc done.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'penc', 'fitness': 4}
#
# gen 58:
# sel inds: ['penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc', 'penc']
# crossover between penc and penc done.
# Crossover failed.
# crossover between penc and penc done.
# Crossover failed.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 3 in [4 : pewc] with mut= 0.015741695851047455. n to w
# 	 {'tag': 4, 'ind': 'pewc', 'fitness': 9}
# 	 {'tag': 5, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'penc', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'penc', 'fitness': 4}
# Mutation in gen 4 in [9 : peng] with mut= 0.031689188831113047. c to g
# ...
# Mutation in gen 2 in [4 : pspd] with mut= 0.04859018688395833. e to s
# 	 {'tag': 4, 'ind': 'pspd', 'fitness': 15}
# 	 {'tag': 5, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 6, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 7, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 3 in [8 : peld] with mut= 0.0390716456060759. p to l
# 	 {'tag': 8, 'ind': 'peld', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'pepf', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'pepf', 'fitness': 1}
#
# gen 190:
# sel inds: ['pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepf', 'pepf', 'pepd']
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# crossover between pepd and pepf done.
# crossover between pepf and pepd done.
# 	 {'tag': 1, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 2, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 3, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 1 in [4 : xepd] with mut= 0.04731398458126557. p to x
# 	 {'tag': 4, 'ind': 'xepd', 'fitness': 9}
# 	 {'tag': 5, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 6, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 1 in [7 : fepf] with mut= 0.01362939614155978. p to f
# 	 {'tag': 7, 'ind': 'fepf', 'fitness': 11}
# 	 {'tag': 8, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'pepf', 'fitness': 1}
#
# gen 191:
# sel inds: ['pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd']
# crossover between pepd and pepd done.
# Crossover failed.
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# 	 {'tag': 1, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 2, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 1 in [3 : sepd] with mut= 0.033118355655597065. p to s
# 	 {'tag': 3, 'ind': 'sepd', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 2 in [5 : pmpd] with mut= 0.004869008966963073. e to m
# 	 {'tag': 5, 'ind': 'pmpd', 'fitness': 9}
# 	 {'tag': 6, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 7, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 8, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'pepd', 'fitness': 1}
#
# gen 192:
# sel inds: ['pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd']
# Crossover failed.
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# 	 {'tag': 1, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 1 in [2 : cepd] with mut= 0.012414662239134566. p to c
# 	 {'tag': 2, 'ind': 'cepd', 'fitness': 14}
# 	 {'tag': 3, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 1 in [4 : tepd] with mut= 0.03548744111619917. p to t
# 	 {'tag': 4, 'ind': 'tepd', 'fitness': 5}
# 	 {'tag': 5, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 6, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 1 in [7 : qepd] with mut= 0.04499303715065783. p to q
# Mutation in gen 3 in [7 : qeid] with mut= 0.047698691864294984. p to i
# 	 {'tag': 7, 'ind': 'qeid', 'fitness': 9}
# 	 {'tag': 8, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'pepd', 'fitness': 1}
#
# gen 193:
# sel inds: ['pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd']
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# Crossover failed.
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# 	 {'tag': 1, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 2, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 3, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 4, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 5, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 4 in [6 : pepg] with mut= 0.013807117929305446. d to g
# 	 {'tag': 6, 'ind': 'pepg', 'fitness': 2}
# Mutation in gen 2 in [7 : pcpd] with mut= 0.04777016059196648. e to c
# 	 {'tag': 7, 'ind': 'pcpd', 'fitness': 3}
# 	 {'tag': 8, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'pepd', 'fitness': 1}
#
# gen 194:
# sel inds: ['pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd']
# Crossover failed.
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 2, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 3, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 4, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 5, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 3 in [6 : pesd] with mut= 0.02880410419917645. p to s
# 	 {'tag': 6, 'ind': 'pesd', 'fitness': 4}
# Mutation in gen 3 in [7 : pedd] with mut= 0.015592528892535706. p to d
# 	 {'tag': 7, 'ind': 'pedd', 'fitness': 13}
# 	 {'tag': 8, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'pepd', 'fitness': 1}
#
# gen 195:
# sel inds: ['pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd']
# Crossover failed.
# Crossover failed.
# crossover between pepd and pepd done.
# Crossover failed.
# crossover between pepd and pepd done.
# 	 {'tag': 1, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 2, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 3, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 4, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 1 in [5 : tepd] with mut= 0.045730418805830064. p to t
# 	 {'tag': 5, 'ind': 'tepd', 'fitness': 5}
# 	 {'tag': 6, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 4 in [7 : pepx] with mut= 0.002050617260171528. d to x
# 	 {'tag': 7, 'ind': 'pepx', 'fitness': 19}
# 	 {'tag': 8, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'pepd', 'fitness': 1}
#
# gen 196:
# sel inds: ['pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd']
# Crossover failed.
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# Crossover failed.
# crossover between pepd and pepd done.
# 	 {'tag': 1, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 2, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 3, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 2 in [4 : pppd] with mut= 0.004786926501528566. e to p
# 	 {'tag': 4, 'ind': 'pppd', 'fitness': 12}
# 	 {'tag': 5, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 6, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 7, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 8, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 1 in [10 : depd] with mut= 0.0368713145259536. p to d
# 	 {'tag': 10, 'ind': 'depd', 'fitness': 13}
#
# gen 197:
# sel inds: ['pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd']
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# Crossover failed.
# crossover between pepd and pepd done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 4 in [2 : pepi] with mut= 0.015277186691329048. d to i
# 	 {'tag': 2, 'ind': 'pepi', 'fitness': 4}
# Mutation in gen 4 in [3 : pepp] with mut= 0.03475372379856034. d to p
# 	 {'tag': 3, 'ind': 'pepp', 'fitness': 11}
# 	 {'tag': 4, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 5, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 4 in [6 : pepf] with mut= 0.028940616895428928. d to f
# 	 {'tag': 6, 'ind': 'pepf', 'fitness': 1}
# 	 {'tag': 7, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 3 in [8 : pexd] with mut= 0.04133972351264503. p to x
# 	 {'tag': 8, 'ind': 'pexd', 'fitness': 9}
# 	 {'tag': 9, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'pepd', 'fitness': 1}
#
# gen 198:
# sel inds: ['pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepf']
# Crossover failed.
# Crossover failed.
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# crossover between pepd and pepf done.
# 	 {'tag': 1, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 2, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 3, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 2 in [4 : popd] with mut= 0.03239660526186716. e to o
# 	 {'tag': 4, 'ind': 'popd', 'fitness': 11}
# 	 {'tag': 5, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 6, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 7, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 8, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'pepf', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'pepd', 'fitness': 1}
#
# gen 199:
# sel inds: ['pepf', 'pepd', 'pepd', 'pepd', 'pepd', 'pepf', 'pepd', 'pepf', 'pepd', 'pepd']
# crossover between pepf and pepd done.
# Crossover failed.
# crossover between pepd and pepf done.
# crossover between pepd and pepf done.
# crossover between pepd and pepd done.
# 	 {'tag': 1, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 4 in [2 : pepm] with mut= 0.04064465632560055. f to m
# 	 {'tag': 2, 'ind': 'pepm', 'fitness': 8}
# 	 {'tag': 3, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 4, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 5, 'ind': 'pepf', 'fitness': 1}
# 	 {'tag': 6, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 4 in [7 : pepv] with mut= 0.010707116578807074. f to v
# 	 {'tag': 7, 'ind': 'pepv', 'fitness': 17}
# 	 {'tag': 8, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'pepd', 'fitness': 1}
#
# gen 200:
# sel inds: ['pepd', 'pepd', 'pepd', 'pepd', 'pepf', 'pepd', 'pepd', 'pepd', 'pepd', 'pepf']
# Crossover failed.
# crossover between pepd and pepd done.
# Crossover failed.
# crossover between pepd and pepd done.
# Crossover failed.
# Mutation in gen 2 in [1 : pbpd] with mut= 0.03167693539512473. e to b
# 	 {'tag': 1, 'ind': 'pbpd', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 4 in [3 : pepa] with mut= 0.02540985423720199. d to a
# 	 {'tag': 3, 'ind': 'pepa', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 5, 'ind': 'pepf', 'fitness': 1}
# 	 {'tag': 6, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 7, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 8, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 2 in [9 : pfpd] with mut= 0.0015548407928949182. e to f
# 	 {'tag': 9, 'ind': 'pfpd', 'fitness': 2}
# 	 {'tag': 10, 'ind': 'pepf', 'fitness': 1}
#
# gen 201:
# sel inds: ['pepd', 'pepf', 'pepd', 'pepd', 'pepd', 'pepf', 'pepd', 'pepd', 'pepd', 'pepd']
# crossover between pepd and pepf done.
# crossover between pepd and pepd done.
# Crossover failed.
# Crossover failed.
# crossover between pepd and pepd done.
# 	 {'tag': 1, 'ind': 'pepf', 'fitness': 1}
# 	 {'tag': 2, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 3, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 4, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 5, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 6, 'ind': 'pepf', 'fitness': 1}
# 	 {'tag': 7, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 8, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'pepd', 'fitness': 1}
#
# gen 202:
# sel inds: ['pepf', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepf', 'pepd', 'pepd', 'pepd']
# Crossover failed.
# crossover between pepd and pepd done.
# Crossover failed.
# crossover between pepf and pepd done.
# crossover between pepd and pepd done.
# 	 {'tag': 1, 'ind': 'pepf', 'fitness': 1}
# Mutation in gen 1 in [2 : wepd] with mut= 0.006512987812575921. p to w
# 	 {'tag': 2, 'ind': 'wepd', 'fitness': 8}
# 	 {'tag': 3, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 4, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 1 in [5 : qepd] with mut= 0.035966574428358045. p to q
# Mutation in gen 3 in [5 : qewd] with mut= 0.03243347230789728. p to w
# 	 {'tag': 5, 'ind': 'qewd', 'fitness': 9}
# 	 {'tag': 6, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 7, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 4 in [8 : peps] with mut= 0.031125997378171677. f to s
# 	 {'tag': 8, 'ind': 'peps', 'fitness': 14}
# 	 {'tag': 9, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'pepd', 'fitness': 1}
#
# gen 203:
# sel inds: ['pepf', 'pepd', 'pepd', 'pepf', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd']
# crossover between pepf and pepd done.
# Crossover failed.
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# Mutation in gen 1 in [1 : jepd] with mut= 0.022560065839955734. p to j
# Mutation in gen 3 in [1 : jegd] with mut= 0.03613240937399942. p to g
# 	 {'tag': 1, 'ind': 'jegd', 'fitness': 16}
# 	 {'tag': 2, 'ind': 'pepf', 'fitness': 1}
# 	 {'tag': 3, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 4, 'ind': 'pepf', 'fitness': 1}
# 	 {'tag': 5, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 6, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 7, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 3 in [8 : peed] with mut= 0.03127911171431297. p to e
# 	 {'tag': 8, 'ind': 'peed', 'fitness': 12}
# 	 {'tag': 9, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 3 in [10 : pexd] with mut= 0.006640209334267344. p to x
# 	 {'tag': 10, 'ind': 'pexd', 'fitness': 9}
#
# gen 204:
# sel inds: ['pepf', 'pepd', 'pepf', 'pepd', 'pepf', 'pepf', 'pepf', 'pepd', 'pepd', 'pepd']
# crossover between pepf and pepd done.
# crossover between pepf and pepd done.
# crossover between pepf and pepf done.
# Crossover failed.
# crossover between pepd and pepd done.
# 	 {'tag': 1, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 2, 'ind': 'pepf', 'fitness': 1}
# Mutation in gen 3 in [3 : pead] with mut= 0.017847079126923737. p to a
# 	 {'tag': 3, 'ind': 'pead', 'fitness': 16}
# Mutation in gen 2 in [4 : pbpf] with mut= 0.046676961651531346. e to b
# 	 {'tag': 4, 'ind': 'pbpf', 'fitness': 4}
# Mutation in gen 1 in [5 : yepf] with mut= 0.028699518578527705. p to y
# 	 {'tag': 5, 'ind': 'yepf', 'fitness': 10}
# 	 {'tag': 6, 'ind': 'pepf', 'fitness': 1}
# 	 {'tag': 7, 'ind': 'pepf', 'fitness': 1}
# 	 {'tag': 8, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'pepd', 'fitness': 1}
#
# gen 205:
# sel inds: ['pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepd', 'pepf', 'pepd', 'pepf']
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# crossover between pepd and pepd done.
# Crossover failed.
# crossover between pepd and pepf done.
# 	 {'tag': 1, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 2, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 3, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 4, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 5, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 6, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 1 in [7 : kepd] with mut= 0.029775581029164777. p to k
# 	 {'tag': 7, 'ind': 'kepd', 'fitness': 6}
# 	 {'tag': 8, 'ind': 'pepf', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'pepf', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'pepd', 'fitness': 1}
#
# gen 206:
# sel inds: ['pepf', 'pepd', 'pepf', 'pepd', 'pepd', 'pepd', 'pepf', 'pepd', 'pepd', 'pepd']
# crossover between pepf and pepd done.
# crossover between pepf and pepd done.
# crossover between pepd and pepd done.
# crossover between pepf and pepd done.
# crossover between pepd and pepd done.
# 	 {'tag': 1, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 2, 'ind': 'pepf', 'fitness': 1}
# Mutation in gen 2 in [3 : pipd] with mut= 0.04858120532757282. e to i
# 	 {'tag': 3, 'ind': 'pipd', 'fitness': 5}
# Mutation in gen 2 in [4 : papf] with mut= 0.0069558062699. e to a
# Mutation in gen 3 in [4 : pawf] with mut= 0.008766846260612526. p to w
# 	 {'tag': 4, 'ind': 'pawf', 'fitness': 12}
# Mutation in gen 3 in [5 : peod] with mut= 0.02810722189414938. p to o
# 	 {'tag': 5, 'ind': 'peod', 'fitness': 2}
# 	 {'tag': 6, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 7, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 3 in [8 : pevf] with mut= 0.0225288062305099. p to v
# 	 {'tag': 8, 'ind': 'pevf', 'fitness': 7}
# 	 {'tag': 9, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'pepd', 'fitness': 1}
#
# gen 207:
# sel inds: ['pepd', 'pepf', 'pepd', 'pepd', 'pepd', 'pepf', 'pepd', 'pepf', 'pepd', 'pepf']
# crossover between pepd and pepf done.
# crossover between pepd and pepd done.
# crossover between pepd and pepf done.
# Crossover failed.
# crossover between pepd and pepf done.
# 	 {'tag': 1, 'ind': 'pepf', 'fitness': 1}
# 	 {'tag': 2, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 4 in [3 : pepe] with mut= 0.006437052776910979. d to e
# 	 {'tag': 3, 'ind': 'pepe', 'fitness': 0}
# 	 {'tag': 4, 'ind': 'pepd', 'fitness': 1}
# 	 {'tag': 5, 'ind': 'pepf', 'fitness': 1}
# 	 {'tag': 6, 'ind': 'pepd', 'fitness': 1}
# Mutation in gen 2 in [7 : pkpd] with mut= 0.0006708751055050088. e to k
# 	 {'tag': 7, 'ind': 'pkpd', 'fitness': 7}
# 	 {'tag': 8, 'ind': 'pepf', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'pepf', 'fitness': 1}
# 	 {'tag': 10, 'ind': 'pepd', 'fitness': 1}
#
# Password found!
# Gen: 207
# Ind: 3
# Password: pepe

# %% [markdown]
# ### Algoritmo genético

# %% [markdown]
# ## Conclusão

# %% [markdown]
# ## Playground
