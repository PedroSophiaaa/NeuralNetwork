# %% [markdown]
# Descobrindo a senha
# ===================

# %% [markdown]
# ## Objetivo

# %% [markdown]
# Usar um algoritmo genético para descobrir uma senha.

# %% [markdown]
# ## Descrição do problema

# %% [markdown]
# Neste problema, a função objetivo deve saber a senha correta e quantificar de alguma maneira o quão perto ou longe os palpites estão da solução (veja que isso é algo que não temos no mundo real. Nenhum site irá te dizer se você está acertando ou errando seu palpite). O critério de parada deste problema é quando a senha for descoberta.

# %% [markdown]
# ## Importações

# %%
from string import printable
from funcoes import new_pop_passw, fitness_passw, tourn_sel_min, crossover_passw, mutation_passw
import random as rd

# %% [markdown]
# ## Códigos e discussão

# %% [markdown]
# ### Gerador de senha

# %%
pass_chars = printable[:-5]

# %%
def create_password(n):
    password = ""
    for i in range(n):
        password += rd.choice(pass_chars)
    return password

# %%
TAM_POP = 10
NUM_GEN = 1000
GEN_MAX = 100
PM = 0.05 # Probabilidade de mutação
PC = 0.75 # Probabilidade de cruzamento
PS = 24 # Número de caracteres da senha

TAM_CROMO = PS

PASSWORD = create_password(PS)
print("Real password: '", PASSWORD, "'", sep='')
# Out:
# Real password: ')?beu#dRqw.9C\;eDPabyOq;'

# %%
PASSWORD = "pepe"
pass_chars = "abcdefghijklmnopqrstuvwxyz"
TAM_CROMO = len(PASSWORD)

# %%
gen = 1
pop = new_pop_passw(TAM_POP, TAM_CROMO, pass_chars, PASSWORD)

min_fit = float('inf')

while min_fit != 0:
    print("gen ", gen, ":", sep="")
    if gen > 1:
        pop = tourn_sel_min(pop, PASSWORD)

        pop_inds = [pop[i]["ind"] for i in pop]
        p1_list = pop_inds[0::2]
        p2_list = pop_inds[1::2]
        c = 1
        for p1, p2 in zip(p1_list, p2_list):
            filho1, filho2 = crossover_passw(p1, p2, PC)
            pop[c]["ind"] = filho1
            pop[c + 1]["ind"] = filho2
            c += 2
    for i in pop:
        curr_ind = pop[i]
        if gen > 1:
            curr_ind = mutation_passw(curr_ind, pass_chars, PM)
        curr_ind["fitness"] = fitness_passw(curr_ind["ind"], PASSWORD)
        print("\t", curr_ind)
    for i in pop:
        if pop[i]['fitness'] == 0:
            best_ind = pop[i]['ind']
            best_ind_tag = pop[i]['tag']
            min_fit = 0
            print(f'\nPassword found!\nGen: {gen}\nInd: {best_ind_tag}\nPassword: {best_ind}')
    gen += 1
    print()
# Out:
# gen 1:
# 	 {'tag': 1, 'ind': 'vuor', 'fitness': 36}
# 	 {'tag': 2, 'ind': 'crbt', 'fitness': 55}
# 	 {'tag': 3, 'ind': 'pued', 'fitness': 28}
# 	 {'tag': 4, 'ind': 'bvhs', 'fitness': 53}
# 	 {'tag': 5, 'ind': 'wdxv', 'fitness': 33}
# 	 {'tag': 6, 'ind': 'eksr', 'fitness': 33}
# 	 {'tag': 7, 'ind': 'nlbt', 'fitness': 38}
# 	 {'tag': 8, 'ind': 'daya', 'fitness': 29}
# 	 {'tag': 9, 'ind': 'ykut', 'fitness': 35}
# 	 {'tag': 10, 'ind': 'mzjm', 'fitness': 38}
#
# gen 2:
# sel inds: ['ykut', 'mzjm', 'vuor', 'vuor', 'wdxv', 'ykut', 'wdxv', 'eksr', 'daya', 'eksr']
# crossover between ykut and mzjm done.
# crossover between vuor and vuor done.
# crossover between wdxv and ykut done.
# crossover between wdxv and eksr done.
# crossover between daya and eksr done.
# 	 {'tag': 1, 'ind': 'ykjm', 'fitness': 29}
# 	 {'tag': 2, 'ind': 'mzut', 'fitness': 44}
# 	 {'tag': 3, 'ind': 'vuor', 'fitness': 36}
# Mutation in gen 3 in [4 : vuhr] with mut= 0.049350690178634804. o to h
# 	 {'tag': 4, 'ind': 'vuhr', 'fitness': 43}
# 	 {'tag': 5, 'ind': 'wkut', 'fitness': 33}
# 	 {'tag': 6, 'ind': 'ydxv', 'fitness': 35}
# 	 {'tag': 7, 'ind': 'wdxr', 'fitness': 29}
# 	 {'tag': 8, 'ind': 'eksv', 'fitness': 37}
# Mutation in gen 3 in [9 : dafr] with mut= 0.0071601042566523665. y to f
# 	 {'tag': 9, 'ind': 'dafr', 'fitness': 39}
# Mutation in gen 3 in [10 : ekca] with mut= 0.009628291665560784. s to c
# 	 {'tag': 10, 'ind': 'ekca', 'fitness': 34}
#
# gen 3:
# sel inds: ['ykjm', 'ekca', 'ykjm', 'ekca', 'ykjm', 'vuor', 'ykjm', 'ykjm', 'wkut', 'ykjm']
# Crossover failed.
# crossover between ykjm and ekca done.
# crossover between ykjm and vuor done.
# crossover between ykjm and ykjm done.
# crossover between wkut and ykjm done.
# 	 {'tag': 1, 'ind': 'ykjm', 'fitness': 29}
# 	 {'tag': 2, 'ind': 'ekca', 'fitness': 34}
# 	 {'tag': 3, 'ind': 'ykja', 'fitness': 25}
# 	 {'tag': 4, 'ind': 'ekcm', 'fitness': 38}
# 	 {'tag': 5, 'ind': 'ykor', 'fitness': 29}
# 	 {'tag': 6, 'ind': 'vujm', 'fitness': 36}
# Mutation in gen 3 in [7 : ykpm] with mut= 0.020234042263438057. j to p
# 	 {'tag': 7, 'ind': 'ykpm', 'fitness': 23}
# 	 {'tag': 8, 'ind': 'ykjm', 'fitness': 29}
# 	 {'tag': 9, 'ind': 'wkum', 'fitness': 26}
# 	 {'tag': 10, 'ind': 'ykjt', 'fitness': 36}
#
# gen 4:
# sel inds: ['ykjm', 'ykpm', 'ykpm', 'ykja', 'ykja', 'ykor', 'ykja', 'ykja', 'ykor', 'ykja']
# crossover between ykjm and ykpm done.
# Crossover failed.
# crossover between ykja and ykor done.
# Crossover failed.
# crossover between ykor and ykja done.
# 	 {'tag': 1, 'ind': 'ykjm', 'fitness': 29}
# 	 {'tag': 2, 'ind': 'ykpm', 'fitness': 23}
# Mutation in gen 2 in [3 : ytpm] with mut= 0.023970825926599604. k to t
# 	 {'tag': 3, 'ind': 'ytpm', 'fitness': 32}
# 	 {'tag': 4, 'ind': 'ykja', 'fitness': 25}
# 	 {'tag': 5, 'ind': 'ykjr', 'fitness': 34}
# 	 {'tag': 6, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 7, 'ind': 'ykja', 'fitness': 25}
# 	 {'tag': 8, 'ind': 'ykja', 'fitness': 25}
# Mutation in gen 3 in [9 : ykoa] with mut= 0.025915813202872395. j to o
# 	 {'tag': 9, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 10, 'ind': 'ykor', 'fitness': 29}
#
# gen 5:
# sel inds: ['ykoa', 'ykja', 'ykoa', 'ykja', 'ykpm', 'ykoa', 'ykja', 'ykoa', 'ykoa', 'ykoa']
# Crossover failed.
# crossover between ykoa and ykja done.
# Crossover failed.
# crossover between ykja and ykoa done.
# crossover between ykoa and ykoa done.
# Mutation in gen 4 in [1 : ykox] with mut= 0.03717346103408259. a to x
# 	 {'tag': 1, 'ind': 'ykox', 'fitness': 35}
# 	 {'tag': 2, 'ind': 'ykja', 'fitness': 25}
# Mutation in gen 4 in [3 : ykow] with mut= 0.0018468075817731355. a to w
# 	 {'tag': 3, 'ind': 'ykow', 'fitness': 34}
# 	 {'tag': 4, 'ind': 'ykja', 'fitness': 25}
# 	 {'tag': 5, 'ind': 'ykpm', 'fitness': 23}
# Mutation in gen 4 in [6 : ykov] with mut= 0.04637883966126277. a to v
# 	 {'tag': 6, 'ind': 'ykov', 'fitness': 33}
# Mutation in gen 3 in [7 : ykua] with mut= 0.015339235445410826. o to u
# 	 {'tag': 7, 'ind': 'ykua', 'fitness': 24}
# 	 {'tag': 8, 'ind': 'ykja', 'fitness': 25}
# 	 {'tag': 9, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 10, 'ind': 'ykoa', 'fitness': 20}
#
# gen 6:
# sel inds: ['ykoa', 'ykoa', 'ykpm', 'ykoa', 'ykoa', 'ykoa', 'ykoa', 'ykpm', 'ykja', 'ykua']
# crossover between ykoa and ykoa done.
# crossover between ykpm and ykoa done.
# Crossover failed.
# crossover between ykoa and ykpm done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 2, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 3, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 4, 'ind': 'ykpm', 'fitness': 23}
# 	 {'tag': 5, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 6, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 7, 'ind': 'ykpm', 'fitness': 23}
# 	 {'tag': 8, 'ind': 'ykoa', 'fitness': 20}
# Mutation in gen 2 in [9 : yzja] with mut= 0.004486050109637207. k to z
# 	 {'tag': 9, 'ind': 'yzja', 'fitness': 40}
# 	 {'tag': 10, 'ind': 'ykua', 'fitness': 24}
#
# gen 7:
# sel inds: ['ykoa', 'ykoa', 'ykoa', 'ykoa', 'ykoa', 'ykoa', 'ykoa', 'ykoa', 'ykoa', 'ykoa']
# Crossover failed.
# Crossover failed.
# Crossover failed.
# Crossover failed.
# crossover between ykoa and ykoa done.
# 	 {'tag': 1, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 2, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 3, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 4, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 5, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 6, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 7, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 8, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 9, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 10, 'ind': 'ykoa', 'fitness': 20}
#
# gen 8:
# sel inds: ['ykoa', 'ykoa', 'ykoa', 'ykoa', 'ykoa', 'ykoa', 'ykoa', 'ykoa', 'ykoa', 'ykoa']
# crossover between ykoa and ykoa done.
# crossover between ykoa and ykoa done.
# crossover between ykoa and ykoa done.
# Crossover failed.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'ykoa', 'fitness': 20}
# Mutation in gen 4 in [2 : ykoe] with mut= 0.03141157895692814. a to e
# 	 {'tag': 2, 'ind': 'ykoe', 'fitness': 16}
# 	 {'tag': 3, 'ind': 'ykoa', 'fitness': 20}
# Mutation in gen 4 in [4 : ykog] with mut= 0.0279896274053425. a to g
# 	 {'tag': 4, 'ind': 'ykog', 'fitness': 18}
# 	 {'tag': 5, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 6, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 7, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 8, 'ind': 'ykoa', 'fitness': 20}
# Mutation in gen 3 in [9 : ykwa] with mut= 0.04402994940807836. o to w
# 	 {'tag': 9, 'ind': 'ykwa', 'fitness': 26}
# 	 {'tag': 10, 'ind': 'ykoa', 'fitness': 20}
#
# gen 9:
# sel inds: ['ykog', 'ykog', 'ykoa', 'ykoa', 'ykog', 'ykoe', 'ykoe', 'ykoe', 'ykoe', 'ykog']
# Crossover failed.
# crossover between ykoa and ykoa done.
# Crossover failed.
# Crossover failed.
# crossover between ykoe and ykog done.
# 	 {'tag': 1, 'ind': 'ykog', 'fitness': 18}
# Mutation in gen 3 in [2 : ykhg] with mut= 0.018218670825074557. o to h
# 	 {'tag': 2, 'ind': 'ykhg', 'fitness': 25}
# 	 {'tag': 3, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 4, 'ind': 'ykoa', 'fitness': 20}
# Mutation in gen 3 in [5 : ykcg] with mut= 0.03591697764691504. o to c
# 	 {'tag': 5, 'ind': 'ykcg', 'fitness': 30}
# 	 {'tag': 6, 'ind': 'ykoe', 'fitness': 16}
# 	 {'tag': 7, 'ind': 'ykoe', 'fitness': 16}
# 	 {'tag': 8, 'ind': 'ykoe', 'fitness': 16}
# Mutation in gen 4 in [9 : ykot] with mut= 0.047854184175493364. g to t
# 	 {'tag': 9, 'ind': 'ykot', 'fitness': 31}
# 	 {'tag': 10, 'ind': 'ykoe', 'fitness': 16}
#
# gen 10:
# sel inds: ['ykoe', 'ykoe', 'ykoe', 'ykoa', 'ykoe', 'ykoe', 'ykog', 'ykog', 'ykoe', 'ykoe']
# crossover between ykoe and ykoe done.
# crossover between ykoe and ykoa done.
# crossover between ykoe and ykoe done.
# crossover between ykog and ykog done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'ykoe', 'fitness': 16}
# Mutation in gen 1 in [2 : ikoe] with mut= 0.041481826896829. y to i
# 	 {'tag': 2, 'ind': 'ikoe', 'fitness': 14}
# 	 {'tag': 3, 'ind': 'ykoa', 'fitness': 20}
# 	 {'tag': 4, 'ind': 'ykoe', 'fitness': 16}
# 	 {'tag': 5, 'ind': 'ykoe', 'fitness': 16}
# Mutation in gen 2 in [6 : yaoe] with mut= 0.026875568132839867. k to a
# 	 {'tag': 6, 'ind': 'yaoe', 'fitness': 14}
# 	 {'tag': 7, 'ind': 'ykog', 'fitness': 18}
# 	 {'tag': 8, 'ind': 'ykog', 'fitness': 18}
# 	 {'tag': 9, 'ind': 'ykoe', 'fitness': 16}
# 	 {'tag': 10, 'ind': 'ykoe', 'fitness': 16}
#
# gen 11:
# sel inds: ['ykoe', 'ykoe', 'yaoe', 'ykog', 'ykoe', 'ykoe', 'ikoe', 'ykoe', 'yaoe', 'yaoe']
# Crossover failed.
# Crossover failed.
# Crossover failed.
# crossover between ikoe and ykoe done.
# crossover between yaoe and yaoe done.
# 	 {'tag': 1, 'ind': 'ykoe', 'fitness': 16}
# 	 {'tag': 2, 'ind': 'ykoe', 'fitness': 16}
# 	 {'tag': 3, 'ind': 'yaoe', 'fitness': 14}
# 	 {'tag': 4, 'ind': 'ykog', 'fitness': 18}
# 	 {'tag': 5, 'ind': 'ykoe', 'fitness': 16}
# 	 {'tag': 6, 'ind': 'ykoe', 'fitness': 16}
# 	 {'tag': 7, 'ind': 'ikoe', 'fitness': 14}
# Mutation in gen 4 in [8 : ykoo] with mut= 0.019237346874375505. e to o
# 	 {'tag': 8, 'ind': 'ykoo', 'fitness': 26}
# 	 {'tag': 9, 'ind': 'yaoe', 'fitness': 14}
# 	 {'tag': 10, 'ind': 'yaoe', 'fitness': 14}
#
# gen 12:
# sel inds: ['ikoe', 'yaoe', 'yaoe', 'yaoe', 'yaoe', 'ykoe', 'yaoe', 'yaoe', 'yaoe', 'ykoe']
# Crossover failed.
# Crossover failed.
# crossover between yaoe and ykoe done.
# crossover between yaoe and yaoe done.
# crossover between yaoe and ykoe done.
# 	 {'tag': 1, 'ind': 'ikoe', 'fitness': 14}
# 	 {'tag': 2, 'ind': 'yaoe', 'fitness': 14}
# 	 {'tag': 3, 'ind': 'yaoe', 'fitness': 14}
# 	 {'tag': 4, 'ind': 'yaoe', 'fitness': 14}
# Mutation in gen 3 in [5 : yace] with mut= 0.03129158613987182. o to c
# 	 {'tag': 5, 'ind': 'yace', 'fitness': 26}
# Mutation in gen 4 in [6 : ykon] with mut= 0.012956688694794272. e to n
# 	 {'tag': 6, 'ind': 'ykon', 'fitness': 25}
# Mutation in gen 4 in [7 : yaoy] with mut= 0.037365405151634445. e to y
# 	 {'tag': 7, 'ind': 'yaoy', 'fitness': 34}
# 	 {'tag': 8, 'ind': 'yaoe', 'fitness': 14}
# 	 {'tag': 9, 'ind': 'ykoe', 'fitness': 16}
# Mutation in gen 4 in [10 : yaos] with mut= 0.031894441096024795. e to s
# 	 {'tag': 10, 'ind': 'yaos', 'fitness': 28}
#
# gen 13:
# sel inds: ['ykoe', 'yaoe', 'yaoe', 'yaoe', 'yaoe', 'yaoe', 'yaoe', 'ikoe', 'yaoe', 'yaoe']
# crossover between ykoe and yaoe done.
# Crossover failed.
# Crossover failed.
# Crossover failed.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'ykoe', 'fitness': 16}
# 	 {'tag': 2, 'ind': 'yaoe', 'fitness': 14}
# 	 {'tag': 3, 'ind': 'yaoe', 'fitness': 14}
# 	 {'tag': 4, 'ind': 'yaoe', 'fitness': 14}
# 	 {'tag': 5, 'ind': 'yaoe', 'fitness': 14}
# Mutation in gen 1 in [6 : raoe] with mut= 0.032200589220918396. y to r
# 	 {'tag': 6, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 7, 'ind': 'yaoe', 'fitness': 14}
# 	 {'tag': 8, 'ind': 'ikoe', 'fitness': 14}
# 	 {'tag': 9, 'ind': 'yaoe', 'fitness': 14}
# 	 {'tag': 10, 'ind': 'yaoe', 'fitness': 14}
#
# gen 14:
# sel inds: ['yaoe', 'yaoe', 'raoe', 'raoe', 'yaoe', 'yaoe', 'raoe', 'yaoe', 'yaoe', 'yaoe']
# crossover between yaoe and yaoe done.
# crossover between raoe and raoe done.
# crossover between yaoe and yaoe done.
# crossover between raoe and yaoe done.
# crossover between yaoe and yaoe done.
# Mutation in gen 1 in [1 : eaoe] with mut= 0.00788972427758694. y to e
# 	 {'tag': 1, 'ind': 'eaoe', 'fitness': 16}
# 	 {'tag': 2, 'ind': 'yaoe', 'fitness': 14}
# 	 {'tag': 3, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 4, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 5, 'ind': 'yaoe', 'fitness': 14}
# 	 {'tag': 6, 'ind': 'yaoe', 'fitness': 14}
# 	 {'tag': 7, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 8, 'ind': 'yaoe', 'fitness': 14}
# 	 {'tag': 9, 'ind': 'yaoe', 'fitness': 14}
# Mutation in gen 2 in [10 : yzoe] with mut= 0.039228715362369715. a to z
# Mutation in gen 4 in [10 : yzoa] with mut= 0.025296934150791373. e to a
# 	 {'tag': 10, 'ind': 'yzoa', 'fitness': 35}
#
# gen 15:
# sel inds: ['raoe', 'raoe', 'raoe', 'yaoe', 'raoe', 'yaoe', 'raoe', 'raoe', 'yaoe', 'raoe']
# crossover between raoe and raoe done.
# crossover between raoe and yaoe done.
# Crossover failed.
# crossover between raoe and raoe done.
# crossover between yaoe and raoe done.
# Mutation in gen 4 in [1 : raof] with mut= 0.04327301901507041. e to f
# 	 {'tag': 1, 'ind': 'raof', 'fitness': 8}
# 	 {'tag': 2, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 3, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 4, 'ind': 'yaoe', 'fitness': 14}
# 	 {'tag': 5, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 6, 'ind': 'yaoe', 'fitness': 14}
# Mutation in gen 3 in [7 : rase] with mut= 0.04171596278085388. o to s
# 	 {'tag': 7, 'ind': 'rase', 'fitness': 9}
# 	 {'tag': 8, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 9, 'ind': 'yaoe', 'fitness': 14}
# 	 {'tag': 10, 'ind': 'raoe', 'fitness': 7}
#
# gen 16:
# sel inds: ['raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'rase', 'raoe', 'raoe', 'raoe', 'raoe']
# crossover between raoe and raoe done.
# crossover between raoe and raoe done.
# crossover between raoe and rase done.
# crossover between raoe and raoe done.
# crossover between raoe and raoe done.
# 	 {'tag': 1, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 2, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 3, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 4, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 5, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 6, 'ind': 'rase', 'fitness': 9}
# 	 {'tag': 7, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 8, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 9, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 10, 'ind': 'raoe', 'fitness': 7}
#
# gen 17:
# sel inds: ['raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe']
# crossover between raoe and raoe done.
# crossover between raoe and raoe done.
# crossover between raoe and raoe done.
# crossover between raoe and raoe done.
# Crossover failed.
# Mutation in gen 4 in [1 : raoj] with mut= 0.03743558325311336. e to j
# 	 {'tag': 1, 'ind': 'raoj', 'fitness': 12}
# 	 {'tag': 2, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 3, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 4, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 5, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 6, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 7, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 8, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 9, 'ind': 'raoe', 'fitness': 7}
# Mutation in gen 3 in [10 : raoe] with mut= 0.03940053426122059. o to o
# 	 {'tag': 10, 'ind': 'raoe', 'fitness': 7}
#
# gen 18:
# sel inds: ['raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe']
# crossover between raoe and raoe done.
# crossover between raoe and raoe done.
# Crossover failed.
# Crossover failed.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 2, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 3, 'ind': 'raoe', 'fitness': 7}
# Mutation in gen 3 in [4 : rage] with mut= 0.005929724792634095. o to g
# 	 {'tag': 4, 'ind': 'rage', 'fitness': 15}
# Mutation in gen 4 in [5 : raos] with mut= 0.04280045000456656. e to s
# 	 {'tag': 5, 'ind': 'raos', 'fitness': 21}
# 	 {'tag': 6, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 7, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 8, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 9, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 10, 'ind': 'raoe', 'fitness': 7}
#
# gen 19:
# sel inds: ['raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe']
# crossover between raoe and raoe done.
# crossover between raoe and raoe done.
# crossover between raoe and raoe done.
# Crossover failed.
# crossover between raoe and raoe done.
# 	 {'tag': 1, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 2, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 3, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 4, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 5, 'ind': 'raoe', 'fitness': 7}
# Mutation in gen 3 in [6 : raye] with mut= 0.03485022347398181. o to y
# 	 {'tag': 6, 'ind': 'raye', 'fitness': 15}
# 	 {'tag': 7, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 8, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 9, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 10, 'ind': 'raoe', 'fitness': 7}
#
# gen 20:
# sel inds: ['raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe']
# crossover between raoe and raoe done.
# Crossover failed.
# crossover between raoe and raoe done.
# crossover between raoe and raoe done.
# crossover between raoe and raoe done.
# Mutation in gen 3 in [1 : rafe] with mut= 0.003317454609718884. o to f
# 	 {'tag': 1, 'ind': 'rafe', 'fitness': 16}
# Mutation in gen 4 in [2 : raoa] with mut= 0.032674519689435355. e to a
# 	 {'tag': 2, 'ind': 'raoa', 'fitness': 11}
# 	 {'tag': 3, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 4, 'ind': 'raoe', 'fitness': 7}
# Mutation in gen 2 in [5 : rcoe] with mut= 0.00970585432522686. a to c
# Mutation in gen 3 in [5 : rcze] with mut= 0.023428233007931953. o to z
# 	 {'tag': 5, 'ind': 'rcze', 'fitness': 14}
# 	 {'tag': 6, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 7, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 8, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 9, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 10, 'ind': 'raoe', 'fitness': 7}
#
# gen 21:
# sel inds: ['raoe', 'raoa', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe']
# crossover between raoe and raoa done.
# crossover between raoe and raoe done.
# Crossover failed.
# Crossover failed.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'raoa', 'fitness': 11}
# Mutation in gen 3 in [2 : race] with mut= 0.0383411083046622. o to c
# 	 {'tag': 2, 'ind': 'race', 'fitness': 19}
# 	 {'tag': 3, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 4, 'ind': 'raoe', 'fitness': 7}
# Mutation in gen 1 in [5 : jaoe] with mut= 0.01945869362827246. r to j
# 	 {'tag': 5, 'ind': 'jaoe', 'fitness': 11}
# 	 {'tag': 6, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 7, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 8, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 9, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 10, 'ind': 'raoe', 'fitness': 7}
#
# gen 22:
# sel inds: ['raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe']
# crossover between raoe and raoe done.
# Crossover failed.
# crossover between raoe and raoe done.
# crossover between raoe and raoe done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 2, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 3, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 4, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 5, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 6, 'ind': 'raoe', 'fitness': 7}
# Mutation in gen 2 in [7 : rsoe] with mut= 0.023967577739268275. a to s
# 	 {'tag': 7, 'ind': 'rsoe', 'fitness': 17}
# 	 {'tag': 8, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 9, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 10, 'ind': 'raoe', 'fitness': 7}
#
# gen 23:
# sel inds: ['raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe']
# crossover between raoe and raoe done.
# crossover between raoe and raoe done.
# Crossover failed.
# crossover between raoe and raoe done.
# crossover between raoe and raoe done.
# Mutation in gen 3 in [1 : raoe] with mut= 0.0042919379760152365. o to o
# 	 {'tag': 1, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 2, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 3, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 4, 'ind': 'raoe', 'fitness': 7}
# Mutation in gen 1 in [5 : oaoe] with mut= 0.021598101254456048. r to o
# 	 {'tag': 5, 'ind': 'oaoe', 'fitness': 6}
# 	 {'tag': 6, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 7, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 8, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 9, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 10, 'ind': 'raoe', 'fitness': 7}
#
# gen 24:
# sel inds: ['raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'raoe', 'oaoe', 'raoe', 'raoe', 'oaoe']
# crossover between raoe and raoe done.
# crossover between raoe and raoe done.
# crossover between raoe and raoe done.
# crossover between oaoe and raoe done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 2, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 3, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 4, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 5, 'ind': 'raoe', 'fitness': 7}
# Mutation in gen 1 in [6 : qaoe] with mut= 0.033173945584560216. r to q
# 	 {'tag': 6, 'ind': 'qaoe', 'fitness': 6}
# 	 {'tag': 7, 'ind': 'oaoe', 'fitness': 6}
# 	 {'tag': 8, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 9, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 10, 'ind': 'oaoe', 'fitness': 6}
#
# gen 25:
# sel inds: ['raoe', 'oaoe', 'qaoe', 'raoe', 'raoe', 'qaoe', 'qaoe', 'qaoe', 'oaoe', 'qaoe']
# crossover between raoe and oaoe done.
# crossover between qaoe and raoe done.
# crossover between raoe and qaoe done.
# Crossover failed.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'raoe', 'fitness': 7}
# 	 {'tag': 2, 'ind': 'oaoe', 'fitness': 6}
# 	 {'tag': 3, 'ind': 'qaoe', 'fitness': 6}
# 	 {'tag': 4, 'ind': 'raoe', 'fitness': 7}
# Mutation in gen 4 in [5 : raok] with mut= 0.014000539159545689. e to k
# 	 {'tag': 5, 'ind': 'raok', 'fitness': 13}
# 	 {'tag': 6, 'ind': 'qaoe', 'fitness': 6}
# 	 {'tag': 7, 'ind': 'qaoe', 'fitness': 6}
# 	 {'tag': 8, 'ind': 'qaoe', 'fitness': 6}
# 	 {'tag': 9, 'ind': 'oaoe', 'fitness': 6}
# 	 {'tag': 10, 'ind': 'qaoe', 'fitness': 6}
#
# gen 26:
# sel inds: ['qaoe', 'oaoe', 'qaoe', 'qaoe', 'oaoe', 'oaoe', 'qaoe', 'oaoe', 'qaoe', 'oaoe']
# Crossover failed.
# crossover between qaoe and qaoe done.
# Crossover failed.
# crossover between qaoe and oaoe done.
# crossover between qaoe and oaoe done.
# 	 {'tag': 1, 'ind': 'qaoe', 'fitness': 6}
# 	 {'tag': 2, 'ind': 'oaoe', 'fitness': 6}
# 	 {'tag': 3, 'ind': 'qaoe', 'fitness': 6}
# Mutation in gen 1 in [4 : faoe] with mut= 0.04277797097700908. q to f
# 	 {'tag': 4, 'ind': 'faoe', 'fitness': 15}
# 	 {'tag': 5, 'ind': 'oaoe', 'fitness': 6}
# 	 {'tag': 6, 'ind': 'oaoe', 'fitness': 6}
# 	 {'tag': 7, 'ind': 'qaoe', 'fitness': 6}
# 	 {'tag': 8, 'ind': 'oaoe', 'fitness': 6}
# Mutation in gen 1 in [9 : paoe] with mut= 0.0037443626965145693. q to p
# 	 {'tag': 9, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 10, 'ind': 'oaoe', 'fitness': 6}
#
# gen 27:
# sel inds: ['paoe', 'oaoe', 'oaoe', 'qaoe', 'paoe', 'qaoe', 'qaoe', 'oaoe', 'oaoe', 'paoe']
# crossover between paoe and oaoe done.
# Crossover failed.
# crossover between paoe and qaoe done.
# crossover between qaoe and oaoe done.
# crossover between oaoe and paoe done.
# Mutation in gen 3 in [1 : pase] with mut= 0.01178324449421575. o to s
# 	 {'tag': 1, 'ind': 'pase', 'fitness': 7}
# 	 {'tag': 2, 'ind': 'oaoe', 'fitness': 6}
# 	 {'tag': 3, 'ind': 'oaoe', 'fitness': 6}
# 	 {'tag': 4, 'ind': 'qaoe', 'fitness': 6}
# 	 {'tag': 5, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 6, 'ind': 'qaoe', 'fitness': 6}
# 	 {'tag': 7, 'ind': 'qaoe', 'fitness': 6}
# 	 {'tag': 8, 'ind': 'oaoe', 'fitness': 6}
# Mutation in gen 1 in [9 : daoe] with mut= 0.03492993060646232. o to d
# 	 {'tag': 9, 'ind': 'daoe', 'fitness': 17}
# 	 {'tag': 10, 'ind': 'paoe', 'fitness': 5}
#
# gen 28:
# sel inds: ['oaoe', 'oaoe', 'paoe', 'qaoe', 'qaoe', 'qaoe', 'oaoe', 'paoe', 'paoe', 'paoe']
# crossover between oaoe and oaoe done.
# crossover between paoe and qaoe done.
# crossover between qaoe and qaoe done.
# crossover between oaoe and paoe done.
# crossover between paoe and paoe done.
# 	 {'tag': 1, 'ind': 'oaoe', 'fitness': 6}
# 	 {'tag': 2, 'ind': 'oaoe', 'fitness': 6}
# Mutation in gen 2 in [3 : pqoe] with mut= 0.02964724084884829. a to q
# 	 {'tag': 3, 'ind': 'pqoe', 'fitness': 13}
# 	 {'tag': 4, 'ind': 'qaoe', 'fitness': 6}
# Mutation in gen 3 in [5 : qaee] with mut= 0.01600368213039527. o to e
# 	 {'tag': 5, 'ind': 'qaee', 'fitness': 16}
# 	 {'tag': 6, 'ind': 'qaoe', 'fitness': 6}
# Mutation in gen 1 in [7 : zaoe] with mut= 0.023647500059869264. o to z
# 	 {'tag': 7, 'ind': 'zaoe', 'fitness': 15}
# 	 {'tag': 8, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 10, 'ind': 'paoe', 'fitness': 5}
#
# gen 29:
# sel inds: ['paoe', 'paoe', 'paoe', 'oaoe', 'qaoe', 'paoe', 'paoe', 'paoe', 'oaoe', 'paoe']
# crossover between paoe and paoe done.
# Crossover failed.
# crossover between qaoe and paoe done.
# Crossover failed.
# crossover between oaoe and paoe done.
# 	 {'tag': 1, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 2, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 3, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 4, 'ind': 'oaoe', 'fitness': 6}
# Mutation in gen 3 in [5 : qafe] with mut= 0.02832452863995294. o to f
# 	 {'tag': 5, 'ind': 'qafe', 'fitness': 15}
# 	 {'tag': 6, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 7, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'oaoe', 'fitness': 6}
# 	 {'tag': 10, 'ind': 'paoe', 'fitness': 5}
#
# gen 30:
# sel inds: ['paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe']
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# Crossover failed.
# Crossover failed.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 2, 'ind': 'paoe', 'fitness': 5}
# Mutation in gen 3 in [3 : pabe] with mut= 0.04625834255307826. o to b
# 	 {'tag': 3, 'ind': 'pabe', 'fitness': 18}
# 	 {'tag': 4, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 5, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 6, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 7, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'paoe', 'fitness': 5}
# Mutation in gen 2 in [10 : pnoe] with mut= 0.013153597764610336. a to n
# 	 {'tag': 10, 'ind': 'pnoe', 'fitness': 10}
#
# gen 31:
# sel inds: ['paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe']
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# 	 {'tag': 1, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 2, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 3, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 4, 'ind': 'paoe', 'fitness': 5}
# Mutation in gen 3 in [5 : pase] with mut= 0.0473165017854158. o to s
# 	 {'tag': 5, 'ind': 'pase', 'fitness': 7}
# 	 {'tag': 6, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 7, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'paoe', 'fitness': 5}
# Mutation in gen 2 in [9 : psoe] with mut= 0.04194254687414789. a to s
# 	 {'tag': 9, 'ind': 'psoe', 'fitness': 15}
# 	 {'tag': 10, 'ind': 'paoe', 'fitness': 5}
#
# gen 32:
# sel inds: ['paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe']
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# Crossover failed.
# crossover between paoe and paoe done.
# 	 {'tag': 1, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 2, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 3, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 4, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 5, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 6, 'ind': 'paoe', 'fitness': 5}
# Mutation in gen 1 in [7 : haoe] with mut= 0.00489977137352593. p to h
# 	 {'tag': 7, 'ind': 'haoe', 'fitness': 13}
# 	 {'tag': 8, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'paoe', 'fitness': 5}
# Mutation in gen 3 in [10 : pafe] with mut= 0.014410676799973099. o to f
# 	 {'tag': 10, 'ind': 'pafe', 'fitness': 14}
#
# gen 33:
# sel inds: ['paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe']
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 2, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 3, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 4, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 5, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 6, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 7, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 10, 'ind': 'paoe', 'fitness': 5}
#
# gen 34:
# sel inds: ['paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe']
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# 	 {'tag': 1, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 2, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 3, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 4, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 5, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 6, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 7, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 9, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 10, 'ind': 'paoe', 'fitness': 5}
#
# gen 35:
# sel inds: ['paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'paoe']
# Crossover failed.
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# 	 {'tag': 1, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 2, 'ind': 'paoe', 'fitness': 5}
# Mutation in gen 2 in [3 : pvoe] with mut= 0.03747804345058048. a to v
# 	 {'tag': 3, 'ind': 'pvoe', 'fitness': 18}
# Mutation in gen 2 in [4 : pboe] with mut= 0.029724005088474947. a to b
# 	 {'tag': 4, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 6, 'ind': 'paoe', 'fitness': 5}
# Mutation in gen 2 in [7 : pkoe] with mut= 0.021530344504457122. a to k
# 	 {'tag': 7, 'ind': 'pkoe', 'fitness': 7}
# 	 {'tag': 8, 'ind': 'paoe', 'fitness': 5}
# Mutation in gen 4 in [9 : paoi] with mut= 0.010161631490728129. e to i
# 	 {'tag': 9, 'ind': 'paoi', 'fitness': 9}
# 	 {'tag': 10, 'ind': 'paoe', 'fitness': 5}
#
# gen 36:
# sel inds: ['paoe', 'paoe', 'paoe', 'paoe', 'paoe', 'pboe', 'pboe', 'paoe', 'pboe', 'pboe']
# crossover between paoe and paoe done.
# crossover between paoe and paoe done.
# crossover between paoe and pboe done.
# crossover between pboe and paoe done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'paoe', 'fitness': 5}
# Mutation in gen 4 in [2 : paoz] with mut= 0.004428062744655792. e to z
# 	 {'tag': 2, 'ind': 'paoz', 'fitness': 26}
# 	 {'tag': 3, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 4, 'ind': 'paoe', 'fitness': 5}
# Mutation in gen 1 in [5 : baoe] with mut= 0.045157879405722356. p to b
# 	 {'tag': 5, 'ind': 'baoe', 'fitness': 19}
# 	 {'tag': 6, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'paoe', 'fitness': 5}
# Mutation in gen 2 in [9 : ploe] with mut= 0.04238569511146906. b to l
# 	 {'tag': 9, 'ind': 'ploe', 'fitness': 8}
# 	 {'tag': 10, 'ind': 'pboe', 'fitness': 4}
#
# gen 37:
# sel inds: ['pboe', 'pboe', 'paoe', 'pboe', 'paoe', 'pboe', 'pboe', 'paoe', 'pboe', 'pboe']
# crossover between pboe and pboe done.
# Crossover failed.
# crossover between paoe and pboe done.
# crossover between pboe and paoe done.
# crossover between pboe and pboe done.
# 	 {'tag': 1, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 4, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'paoe', 'fitness': 5}
# Mutation in gen 2 in [6 : pboe] with mut= 0.033531948261450006. b to b
# 	 {'tag': 6, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'paoe', 'fitness': 5}
# 	 {'tag': 8, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 4 in [10 : pboz] with mut= 0.022000974245195315. e to z
# 	 {'tag': 10, 'ind': 'pboz', 'fitness': 25}
#
# gen 38:
# sel inds: ['pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe']
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# Crossover failed.
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# 	 {'tag': 1, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 1 in [3 : fboe] with mut= 0.004131362869399968. p to f
# 	 {'tag': 3, 'ind': 'fboe', 'fitness': 14}
# 	 {'tag': 4, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 2 in [5 : pxoe] with mut= 0.025231443868121928. b to x
# 	 {'tag': 5, 'ind': 'pxoe', 'fitness': 20}
# 	 {'tag': 6, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'pboe', 'fitness': 4}
#
# gen 39:
# sel inds: ['pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe']
# Crossover failed.
# crossover between pboe and pboe done.
# Crossover failed.
# crossover between pboe and pboe done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 1 in [6 : fboe] with mut= 0.02356510246311616. p to f
# Mutation in gen 4 in [6 : fbog] with mut= 0.03779194830558208. e to g
# 	 {'tag': 6, 'ind': 'fbog', 'fitness': 16}
# 	 {'tag': 7, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'pboe', 'fitness': 4}
#
# gen 40:
# sel inds: ['pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe']
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# 	 {'tag': 1, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 4 in [7 : pboc] with mut= 0.0276739693404211. e to c
# 	 {'tag': 7, 'ind': 'pboc', 'fitness': 6}
# 	 {'tag': 8, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'pboe', 'fitness': 4}
#
# gen 41:
# sel inds: ['pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe']
# crossover between pboe and pboe done.
# Crossover failed.
# Crossover failed.
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# 	 {'tag': 1, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 1 in [2 : rboe] with mut= 0.019765533632269183. p to r
# Mutation in gen 4 in [2 : rbog] with mut= 0.01979141432452758. e to g
# 	 {'tag': 2, 'ind': 'rbog', 'fitness': 8}
# 	 {'tag': 3, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 1 in [6 : oboe] with mut= 0.0077464489924927715. p to o
# 	 {'tag': 6, 'ind': 'oboe', 'fitness': 5}
# 	 {'tag': 7, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'pboe', 'fitness': 4}
#
# gen 42:
# sel inds: ['pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe']
# crossover between pboe and pboe done.
# Crossover failed.
# crossover between pboe and pboe done.
# Crossover failed.
# crossover between pboe and pboe done.
# 	 {'tag': 1, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 4 in [3 : pboe] with mut= 0.033141965919752714. e to e
# 	 {'tag': 3, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 4 in [4 : pbok] with mut= 0.0029733006324086375. e to k
# 	 {'tag': 4, 'ind': 'pbok', 'fitness': 10}
# 	 {'tag': 5, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'pboe', 'fitness': 4}
#
# gen 43:
# sel inds: ['pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe']
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# 	 {'tag': 1, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 3 in [9 : pbne] with mut= 0.0015032029780308598. o to n
# 	 {'tag': 9, 'ind': 'pbne', 'fitness': 5}
# 	 {'tag': 10, 'ind': 'pboe', 'fitness': 4}
#
# gen 44:
# sel inds: ['pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe']
# crossover between pboe and pboe done.
# Crossover failed.
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# 	 {'tag': 1, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 1 in [4 : kboe] with mut= 0.04376800761906163. p to k
# 	 {'tag': 4, 'ind': 'kboe', 'fitness': 9}
# 	 {'tag': 5, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'pboe', 'fitness': 4}
#
# gen 45:
# sel inds: ['pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe']
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# Crossover failed.
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# Mutation in gen 3 in [1 : pboe] with mut= 0.006235438586583042. o to o
# 	 {'tag': 1, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 3 in [2 : pbre] with mut= 0.0004911527307318586. o to r
# 	 {'tag': 2, 'ind': 'pbre', 'fitness': 5}
# Mutation in gen 2 in [3 : pjoe] with mut= 0.037508644244330425. b to j
# 	 {'tag': 3, 'ind': 'pjoe', 'fitness': 6}
# 	 {'tag': 4, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'pboe', 'fitness': 4}
#
# gen 46:
# sel inds: ['pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe']
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 1 in [4 : tboe] with mut= 0.03430196675703323. p to t
# Mutation in gen 4 in [4 : tbot] with mut= 0.03197934449732154. e to t
# 	 {'tag': 4, 'ind': 'tbot', 'fitness': 23}
# 	 {'tag': 5, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 4 in [6 : pboj] with mut= 0.010237439879137389. e to j
# 	 {'tag': 6, 'ind': 'pboj', 'fitness': 9}
# 	 {'tag': 7, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 10, 'ind': 'pboe', 'fitness': 4}
#
# gen 47:
# sel inds: ['pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe', 'pboe']
# crossover between pboe and pboe done.
# Crossover failed.
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# crossover between pboe and pboe done.
# Mutation in gen 1 in [1 : pboe] with mut= 0.0127622768046316. p to p
# 	 {'tag': 1, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 4, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 5, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 6, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 2 in [7 : pfoe] with mut= 0.020442395114915857. b to f
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 8, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 9, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 1 in [10 : bboe] with mut= 0.03303883975797195. p to b
# 	 {'tag': 10, 'ind': 'bboe', 'fitness': 18}
#
# gen 48:
# sel inds: ['pfoe', 'pboe', 'pboe', 'pfoe', 'pfoe', 'pfoe', 'pboe', 'pfoe', 'pboe', 'pboe']
# crossover between pfoe and pboe done.
# crossover between pboe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pboe and pfoe done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 2, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 2 in [3 : pzoe] with mut= 0.005577227000287732. b to z
# 	 {'tag': 3, 'ind': 'pzoe', 'fitness': 22}
# 	 {'tag': 4, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 5, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 6, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 8, 'ind': 'pboe', 'fitness': 4}
# Mutation in gen 2 in [9 : pcoe] with mut= 0.007283063042945348. b to c
# 	 {'tag': 9, 'ind': 'pcoe', 'fitness': 3}
# 	 {'tag': 10, 'ind': 'pboe', 'fitness': 4}
#
# gen 49:
# sel inds: ['pfoe', 'pboe', 'pfoe', 'pfoe', 'pfoe', 'pcoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe']
# Crossover failed.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pcoe done.
# Crossover failed.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 2, 'ind': 'pboe', 'fitness': 4}
# 	 {'tag': 3, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 1 in [4 : lfoe] with mut= 0.0490939747145297. p to l
# 	 {'tag': 4, 'ind': 'lfoe', 'fitness': 6}
# Mutation in gen 4 in [5 : pcob] with mut= 0.030789343724159424. e to b
# 	 {'tag': 5, 'ind': 'pcob', 'fitness': 6}
# 	 {'tag': 6, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 8, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 9, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 3 in [10 : pfhe] with mut= 0.026183045259589477. o to h
# 	 {'tag': 10, 'ind': 'pfhe', 'fitness': 9}
#
# gen 50:
# sel inds: ['pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe']
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# 	 {'tag': 1, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 1 in [2 : zfoe] with mut= 0.028953857502327374. p to z
# Mutation in gen 3 in [2 : zfre] with mut= 0.029477821454923836. o to r
# 	 {'tag': 2, 'ind': 'zfre', 'fitness': 13}
# 	 {'tag': 3, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 2 in [4 : pjoe] with mut= 0.011887828244684373. f to j
# 	 {'tag': 4, 'ind': 'pjoe', 'fitness': 6}
# 	 {'tag': 5, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 2 in [6 : psoe] with mut= 0.04542714543469195. f to s
# 	 {'tag': 6, 'ind': 'psoe', 'fitness': 15}
# Mutation in gen 4 in [7 : pfoc] with mut= 0.01329866902450838. e to c
# 	 {'tag': 7, 'ind': 'pfoc', 'fitness': 4}
# 	 {'tag': 8, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 9, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 10, 'ind': 'pfoe', 'fitness': 2}
#
# gen 51:
# sel inds: ['pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe']
# Crossover failed.
# Crossover failed.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# 	 {'tag': 1, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 3 in [2 : pfde] with mut= 0.010742344707348472. o to d
# Mutation in gen 4 in [2 : pfdh] with mut= 0.020154710264370546. e to h
# 	 {'tag': 2, 'ind': 'pfdh', 'fitness': 16}
# 	 {'tag': 3, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 4, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 5, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 6, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 1 in [7 : cfoe] with mut= 0.013407275643086636. p to c
# 	 {'tag': 7, 'ind': 'cfoe', 'fitness': 15}
# Mutation in gen 1 in [8 : qfoe] with mut= 0.035913536782018474. p to q
# Mutation in gen 4 in [8 : qfoo] with mut= 0.04227712372699577. e to o
# 	 {'tag': 8, 'ind': 'qfoo', 'fitness': 13}
# 	 {'tag': 9, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 10, 'ind': 'pfoe', 'fitness': 2}
#
# gen 52:
# sel inds: ['pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe']
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# 	 {'tag': 1, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 2, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 1 in [3 : lfoe] with mut= 0.006110548701482643. p to l
# 	 {'tag': 3, 'ind': 'lfoe', 'fitness': 6}
# 	 {'tag': 4, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 5, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 6, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 4 in [8 : pfof] with mut= 0.04635372546917793. e to f
# 	 {'tag': 8, 'ind': 'pfof', 'fitness': 3}
# 	 {'tag': 9, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 10, 'ind': 'pfoe', 'fitness': 2}
#
# gen 53:
# sel inds: ['pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe']
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 2, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 3, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 4, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 5, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 6, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 8, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 2 in [9 : pkoe] with mut= 0.020231933369205035. f to k
# 	 {'tag': 9, 'ind': 'pkoe', 'fitness': 7}
# 	 {'tag': 10, 'ind': 'pfoe', 'fitness': 2}
#
# gen 54:
# sel inds: ['pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe']
# Crossover failed.
# crossover between pfoe and pfoe done.
# Crossover failed.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# 	 {'tag': 1, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 2, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 1 in [3 : bfoe] with mut= 0.03703735546650799. p to b
# 	 {'tag': 3, 'ind': 'bfoe', 'fitness': 16}
# Mutation in gen 4 in [4 : pfoe] with mut= 0.020070893049704774. e to e
# 	 {'tag': 4, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 5, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 6, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 8, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 9, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 10, 'ind': 'pfoe', 'fitness': 2}
#
# gen 55:
# sel inds: ['pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe']
# Crossover failed.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# Mutation in gen 1 in [1 : yfoe] with mut= 0.004870237494553509. p to y
# 	 {'tag': 1, 'ind': 'yfoe', 'fitness': 11}
# 	 {'tag': 2, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 3, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 4, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 5, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 6, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 8, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 1 in [9 : nfoe] with mut= 0.0115529715876449. p to n
# Mutation in gen 3 in [9 : nfle] with mut= 0.012307000960844028. o to l
# 	 {'tag': 9, 'ind': 'nfle', 'fitness': 7}
# 	 {'tag': 10, 'ind': 'pfoe', 'fitness': 2}
#
# gen 56:
# sel inds: ['pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe']
# crossover between pfoe and pfoe done.
# Crossover failed.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# Crossover failed.
# Mutation in gen 1 in [1 : rfoe] with mut= 0.02131763367046824. p to r
# 	 {'tag': 1, 'ind': 'rfoe', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 3, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 4, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 4 in [5 : pfox] with mut= 0.025665432376554942. e to x
# 	 {'tag': 5, 'ind': 'pfox', 'fitness': 21}
# 	 {'tag': 6, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 8, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 9, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 10, 'ind': 'pfoe', 'fitness': 2}
#
# gen 57:
# sel inds: ['pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe']
# crossover between pfoe and pfoe done.
# Crossover failed.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# Mutation in gen 1 in [1 : cfoe] with mut= 0.014919648073644431. p to c
# 	 {'tag': 1, 'ind': 'cfoe', 'fitness': 15}
# Mutation in gen 3 in [2 : pfqe] with mut= 0.04162155889208208. o to q
# 	 {'tag': 2, 'ind': 'pfqe', 'fitness': 2}
# 	 {'tag': 3, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 4, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 5, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 1 in [6 : xfoe] with mut= 0.022412641344115247. p to x
# 	 {'tag': 6, 'ind': 'xfoe', 'fitness': 10}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 1 in [8 : zfoe] with mut= 0.01841602998011249. p to z
# 	 {'tag': 8, 'ind': 'zfoe', 'fitness': 12}
# 	 {'tag': 9, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 10, 'ind': 'pfoe', 'fitness': 2}
#
# gen 58:
# sel inds: ['pfoe', 'pfoe', 'pfqe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe']
# Crossover failed.
# crossover between pfqe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# Mutation in gen 4 in [1 : pfoc] with mut= 0.00041614619269525477. e to c
# 	 {'tag': 1, 'ind': 'pfoc', 'fitness': 4}
# 	 {'tag': 2, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 3, 'ind': 'pfqe', 'fitness': 2}
# 	 {'tag': 4, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 5, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 2 in [6 : phoe] with mut= 0.003847943421230071. f to h
# 	 {'tag': 6, 'ind': 'phoe', 'fitness': 4}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 8, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 9, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 10, 'ind': 'pfoe', 'fitness': 2}
#
# gen 59:
# sel inds: ['pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe']
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# Mutation in gen 3 in [1 : pfte] with mut= 0.010332476403919877. o to t
# 	 {'tag': 1, 'ind': 'pfte', 'fitness': 5}
# 	 {'tag': 2, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 3, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 4, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 4 in [5 : pfot] with mut= 0.03522783327400558. e to t
# 	 {'tag': 5, 'ind': 'pfot', 'fitness': 17}
# 	 {'tag': 6, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 8, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 9, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 10, 'ind': 'pfoe', 'fitness': 2}
#
# gen 60:
# sel inds: ['pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe']
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# Crossover failed.
# Crossover failed.
# crossover between pfoe and pfoe done.
# Mutation in gen 3 in [1 : pffe] with mut= 0.02115944959191951. o to f
# 	 {'tag': 1, 'ind': 'pffe', 'fitness': 11}
# 	 {'tag': 2, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 3, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 4, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 3 in [5 : pfte] with mut= 0.023100675045962138. o to t
# 	 {'tag': 5, 'ind': 'pfte', 'fitness': 5}
# 	 {'tag': 6, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 8, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 9, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 4 in [10 : pfoc] with mut= 0.014631930752445177. e to c
# 	 {'tag': 10, 'ind': 'pfoc', 'fitness': 4}
#
# gen 61:
# sel inds: ['pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe']
# crossover between pfoe and pfoe done.
# Crossover failed.
# crossover between pfoe and pfoe done.
# Crossover failed.
# crossover between pfoe and pfoe done.
# 	 {'tag': 1, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 2, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 3, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 4, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 5, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 1 in [6 : vfoe] with mut= 0.032777538496545855. p to v
# 	 {'tag': 6, 'ind': 'vfoe', 'fitness': 8}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 8, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 3 in [9 : pfke] with mut= 0.021649346803790603. o to k
# 	 {'tag': 9, 'ind': 'pfke', 'fitness': 6}
# 	 {'tag': 10, 'ind': 'pfoe', 'fitness': 2}
#
# gen 62:
# sel inds: ['pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe']
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# Crossover failed.
# crossover between pfoe and pfoe done.
# 	 {'tag': 1, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 2, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 4 in [3 : pfor] with mut= 0.004486681780923818. e to r
# 	 {'tag': 3, 'ind': 'pfor', 'fitness': 15}
# Mutation in gen 1 in [4 : ufoe] with mut= 0.0057213634976717165. p to u
# 	 {'tag': 4, 'ind': 'ufoe', 'fitness': 7}
# 	 {'tag': 5, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 3 in [6 : pfhe] with mut= 0.036158339150257124. o to h
# Mutation in gen 4 in [6 : pfhw] with mut= 0.002996713698618758. e to w
# 	 {'tag': 6, 'ind': 'pfhw', 'fitness': 27}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 8, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 9, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 10, 'ind': 'pfoe', 'fitness': 2}
#
# gen 63:
# sel inds: ['pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe']
# crossover between pfoe and pfoe done.
# Crossover failed.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# Mutation in gen 1 in [1 : gfoe] with mut= 0.022562020999246313. p to g
# 	 {'tag': 1, 'ind': 'gfoe', 'fitness': 11}
# 	 {'tag': 2, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 3, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 4, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 1 in [5 : efoe] with mut= 0.02340860979530901. p to e
# 	 {'tag': 5, 'ind': 'efoe', 'fitness': 13}
# 	 {'tag': 6, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 8, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 9, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 10, 'ind': 'pfoe', 'fitness': 2}
#
# gen 64:
# sel inds: ['pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe']
# Crossover failed.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 2, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 3, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 3 in [4 : pfle] with mut= 0.009870239839869566. o to l
# 	 {'tag': 4, 'ind': 'pfle', 'fitness': 5}
# 	 {'tag': 5, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 6, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 8, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 3 in [9 : pfve] with mut= 0.03513210504589115. o to v
# 	 {'tag': 9, 'ind': 'pfve', 'fitness': 7}
# 	 {'tag': 10, 'ind': 'pfoe', 'fitness': 2}
#
# gen 65:
# sel inds: ['pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe']
# Crossover failed.
# crossover between pfoe and pfoe done.
# crossover between pfoe and pfoe done.
# Crossover failed.
# Crossover failed.
# 	 {'tag': 1, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 4 in [2 : pfom] with mut= 0.02176847154219197. e to m
# 	 {'tag': 2, 'ind': 'pfom', 'fitness': 10}
# 	 {'tag': 3, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 4, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 5, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 3 in [6 : pfpe] with mut= 0.002356022413186998. o to p
# 	 {'tag': 6, 'ind': 'pfpe', 'fitness': 1}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 8, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 9, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 10, 'ind': 'pfoe', 'fitness': 2}
#
# gen 66:
# sel inds: ['pfpe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfoe', 'pfpe', 'pfoe', 'pfoe', 'pfoe']
# crossover between pfpe and pfoe done.
# Crossover failed.
# crossover between pfoe and pfoe done.
# crossover between pfpe and pfoe done.
# crossover between pfoe and pfoe done.
# 	 {'tag': 1, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 2, 'ind': 'pfpe', 'fitness': 1}
# 	 {'tag': 3, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 4, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 5, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 6, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 8, 'ind': 'pfpe', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 10, 'ind': 'pfoe', 'fitness': 2}
#
# gen 67:
# sel inds: ['pfpe', 'pfpe', 'pfoe', 'pfpe', 'pfpe', 'pfoe', 'pfpe', 'pfoe', 'pfoe', 'pfoe']
# crossover between pfpe and pfpe done.
# crossover between pfoe and pfpe done.
# Crossover failed.
# crossover between pfpe and pfoe done.
# crossover between pfoe and pfoe done.
# 	 {'tag': 1, 'ind': 'pfpe', 'fitness': 1}
# 	 {'tag': 2, 'ind': 'pfpe', 'fitness': 1}
# 	 {'tag': 3, 'ind': 'pfpe', 'fitness': 1}
# 	 {'tag': 4, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 5, 'ind': 'pfpe', 'fitness': 1}
# 	 {'tag': 6, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 7, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 8, 'ind': 'pfpe', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'pfoe', 'fitness': 2}
# 	 {'tag': 10, 'ind': 'pfoe', 'fitness': 2}
#
# gen 68:
# sel inds: ['pfpe', 'pfoe', 'pfpe', 'pfpe', 'pfpe', 'pfoe', 'pfoe', 'pfpe', 'pfpe', 'pfpe']
# crossover between pfpe and pfoe done.
# crossover between pfpe and pfpe done.
# crossover between pfpe and pfoe done.
# crossover between pfoe and pfpe done.
# crossover between pfpe and pfpe done.
# Mutation in gen 3 in [1 : pfye] with mut= 0.047033781567288435. p to y
# 	 {'tag': 1, 'ind': 'pfye', 'fitness': 10}
# 	 {'tag': 2, 'ind': 'pfoe', 'fitness': 2}
# Mutation in gen 2 in [3 : pepe] with mut= 0.04771816641526461. f to e
# 	 {'tag': 3, 'ind': 'pepe', 'fitness': 0}
# Mutation in gen 1 in [4 : cfpe] with mut= 0.006017304938556123. p to c
# 	 {'tag': 4, 'ind': 'cfpe', 'fitness': 14}
# Mutation in gen 1 in [5 : hfoe] with mut= 0.040818139710726786. p to h
# 	 {'tag': 5, 'ind': 'hfoe', 'fitness': 10}
# 	 {'tag': 6, 'ind': 'pfpe', 'fitness': 1}
# Mutation in gen 2 in [7 : pooe] with mut= 0.04144766797928179. f to o
# 	 {'tag': 7, 'ind': 'pooe', 'fitness': 11}
# 	 {'tag': 8, 'ind': 'pfpe', 'fitness': 1}
# 	 {'tag': 9, 'ind': 'pfpe', 'fitness': 1}
# Mutation in gen 3 in [10 : pfhe] with mut= 0.005096698112796005. p to h
# 	 {'tag': 10, 'ind': 'pfhe', 'fitness': 9}
#
# Password found!
# Gen: 68
# Ind: 3
# Password: pepe

# %% [markdown]
# ### Algoritmo genético

# %% [markdown]
# ## Conclusão

# %% [markdown]
# ## Playground
